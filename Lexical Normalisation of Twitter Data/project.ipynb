# %% [markdown]
# ## Project 1: Lexical Normalisation of Twitter Data

# %% [markdown]
# ---
# ### Overview
#
# The goal of this Project is to assess the performance of some spelling correction methods on the problem
# of tweet normalisation, and to express the knowledge that you have gained in a technical report. This
# aims to reinforce concepts in approximate matching and evaluation, and to strengthen your skills in data
# analysis and problem solving.
#
# ### Deliverables
#
# 1. One or more programs, implemented in one or more programming languages, which must:
#     - Determine the best match(es) for a token, with respect to a reference collection (dictionary)
#     - Process the data input file(s), to determine the best match for each token
#     - Evaluate the matches, with respect to the truly intended words, using one or more evaluation
#        metrics
# 2. A README thatbrieflydetails how your program(s) work(s). You may use any external re-
#     sources for your program(s) that you wish: you must indicate these, and where you obtained
#     them, in your README. The program(s) and README are required submission elements, but
#     will not typically be directly assessed.
# 3. A technical report, of 1000–1600 words, which must:
#     - Give a short description of the problem and data set
#     - Brieflysummarise some relevant literature
#     - Briefly explain the approximate matching technique(s), and how it is (they are) used
#     - Present the results, in terms of the evaluation metric(s) and illustrative examples
#     - Contextualise the system’s behaviour, based on the (admittedly incomplete) understanding
#        from the subject materials
#     - Clearlydemonstrate some knowledge about the problem
#
# ### Assessment Criteria
#
# Method: (20% of the marks available)
# You will attempt a representative sample of approximate matching techniques, which is adequate for
# deriving some knowledge about the problem of tweet normalisation. You will evaluate your method(s)
# formally.
#
# Critical Analysis: (50% of the marks available)
# You will explain the practical behaviour of your systems, referring to the theoretical behaviour where
# appropriate. You will support your observations with evidence, in terms of illustrative examples and
# evaluation metrics. You will derive some knowledge about the problem of tweet normalisation.
#
# Report Quality: (30% of the marks available)
# You will produce a formal report, which is commensurate in style and structure with a (short) research
# paper. You must express your ideas clearly and concisely, and remain within the word limit (1000-
# words). You will include a short summary of related research.
#
# We will post a marking rubric to indicate what we will be looking for in each of these categories
# when marking.

# %% [markdown]
# ---
# ### Read Me
#
# The data package is in 6 files:
#
#       README.txt: this file, which describes the data and its format.
#
#       {labelled,unlabelled}-tweets.txt: A list of tweets, one per line.  Each tweet
#       is comprised of a space-delimited list of tokens. The tweets have been
#       case-folded, where any upper-case (English) characters have been converted to
#       their lower-case equivalent.
#
#       {labelled,unlabelled}-tokens.txt: A list of tokens, one per line. The tokens
#       are drawn from the tweets above, excepts that tokens not containing at least
#       one (English) alphabetical character - like "." or "!!" - have been excluded.
#       The order of the tokens corresponds to the tweets; no indication of the tweet
#       boundary is given, but this can be recovered from the tweets files as
#       necessary.
#
#   The format of these files follows.
#
#   For the labelled tweets:
#
#       Token TAB Code TAB Canonical_Form
#
#   Where "Token" is drawn from the tweet text (suitably down-cased),
#
#  "Canonical_Form" is the normalised version of the token, and "Code" can take
#   one of three values:
#
#     IV - "in vocabulary", such that the form from the tweet was found in the
#     dictionary, and is consequently not a candidate for normalisation. (There
#     are some exceptions to this, which can be construed as mistakes in the
#     data.)
#
#     OOV - "out of vocabulary", such that the form of the token from the tweet
#     was not found in the dictionary, and thus the token was a candidate for
#     normalisation. In some cases, the canonical form is homologous (equivalent)
#     to the un-normalised form. In other cases, they are different --- these are
#     the "spelling mistakes" that need to be "corrected", in light of the
#     Project requirements.
#
#     NO - "not a normalisation candidate", such that the token was not
#     considered in the normalisation process.
#
#   For example:
#
#         new     IV      new
#
#   "new" is in the dictionary, so its canonical form is equivalent to its form
#   from the tweet.
#
#         pix     OOV     pictures
#
#   "pix" is not in the dictionary, and its canonical form is "pictures".
#
#         #heatchuuuuu    NO      #heatchuuuuu
#
#   "#heatchuuuuu" is not in the dictionary, but it is a Twitter hashtag, and
#   consequently was not regarded as a candidate for normalisation.
#
#   For the unlabelled tweets:
#
#        token TAB ???
#
#   Where "token" is drawn from the tweet text (suitably down-cased). The "code"
#   and "canonical form" are not given. If you wish to test your system on this
#   dataset, you can submit to Kaggle, as explained on the LMS.
#
#   For example:
#
#         rt      ???
#
#   "rt" may or may not be in the dictionary, and there may or may not be a
#   canonical form for this token.
#
# ---

# %% [markdown]
# ### Preamble

# %%
import editdistance
import jellyfish as jf
from collections import Counter
import re
from autocorrect import spell
import nltk
import py_stringmatching as sm

porter = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()
snowball = nltk.SnowballStemmer("english", ignore_stopwords=True)
wnl = nltk.WordNetLemmatizer()

# %% [markdown]
# ### Step 1 – Levenshtein Distance
#
# Once a candidate has been identified for normalisation, firstly,
# edit distance (Levenshtein distance) technique is applied to find matches from (dict.txt)
# which are within 2 (inclusive) edit distance of the query. The results are stored in an array.
# We refer to this set as the “First Set of Matches based on Edit Distance”
# since they contain approximate matches based on their textual similarity to the query.

# %%
def levenshtein_distance(string, dictionary):   
    distance_dict = [x for x in dictionary if editdistance.eval(string, x) <= 2]
    return distance_dict

# %% [markdown]
# ### Step 2 – Phonetic Matching
#
# Soundex is used to further analyse and phonetically match words gathered in the first set, based on their Levenshtein distance to the query. The words in the array are filtered based on their phonetic similarity to the query using soundex, refined soundex and metaphone, etc.

# %%
from pyphonetics import RefinedSoundex
rs = RefinedSoundex()
def soundex_filter(string, dictionary):
    
    filter_once = [x for x in dictionary if rs.distance(string, x, metric='levenshtein') == 0] 
#     filter_twice = [x for x in filter_once if jf.metaphone(x) == jf.metaphone(string)] 
    
    return filter_once

# %% [markdown]
# ### Step 3 – [Peter Norvig’s Algorithm](http://norvig.com/spell-correct.html)
#
# Algorithm generates all possible terms with an edit distance of less than or equal to 2 (which includes deletes, transposes, replaces, and inserts) from the query term and searches them in the dictionary (big.txt).

# %%
# source: http://norvig.com/spell-correct.html
# author: Peter Norvig

def words(text): return re.findall(r'\w+', text.lower())

WORDS = Counter(words(open('big.txt').read()))

def P(word, N=sum(WORDS.values())): 
    "Probability of `word`."
    return WORDS[word] / N

def correction(word): 
    "Most probable spelling correction for word."
    return max(candidates(word), key=P)

def candidates(word): 
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits1(word)) or known(edits2(word)) or [word])

def known(words): 
    "The subset of `words` that appear in the dictionary of WORDS."
    return set(w for w in words if w in WORDS)

def edits1(word):
    "All edits that are one edit away from `word`."
    letters    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def edits2(word): 
    "All edits that are two edits away from `word`."
    return (e2 for e1 in edits1(word) for e2 in edits1(e1))

# %% [markdown]
# ### Step 4 – More Spell Checking
#
# Using Peter Norvig’s Algorithm, python autocorrect package and other stemmers from nltk library to perform a cross-evaluation of the spell chekcer results.

# %%
def spellChecking(candidate):
    wordlist = []
    wordlist.append(correction(candidate))
    wordlist.append(spell(candidate))
    #wordlist.append(porter.stem(candidate))
    #wordlist.append(lancaster.stem(candidate))
    wordlist.append(snowball.stem(candidate))
    #wordlist.append(wnl.lemmatize(candidate))
    
    return wordlist

# %% [markdown]
# ## Normalisation of Unlabelled Tokens

# %% [markdown]
# ### Step 5 - [CMU Twitter POS Tagger](http://www.cs.cmu.edu/~ark/TweetNLP/)
#
# Using CMU twitter part-of-speench tagger to preprocess the unlabelled tokens and further narrow down potential candidates for normalisation

# %%
tags = open('POS.txt', 'r', encoding='latin-1')
tag = {}
for line in tags:
    words = line.split()
    tag[words[0]] = (words[1],words[2])

# %% [markdown]
# ### Step 6 - Using various lexical normalisation dictionaries

# %%
def most_common(lst):
    data = Counter(lst)
    return data.most_common(1)[0][0]

f =  open('labelled-tokens.txt', encoding='latin-1')

labelled_tokens = {}
for line in f:
    words = line.split()
    if words[0] in labelled_tokens:
        labelled_tokens[words[0]].append(words[2])
    else:
        labelled_tokens[words[0]] = [words[2]]

for key, value in labelled_tokens.items():
    labelled_tokens[key] = most_common(labelled_tokens[key])
    
f.close()

# %%
f3 = open('Test_Set_3802_Pairs.txt')

dict3 = {}

for line in f3:
    words = line.split()
    if int(words[0]) >= 4:  
        dict3[words[1]] = words[3]

f3.close()

# %%
f3 = open('Test_Set_3802_Pairs.txt')

dict3_complete = {}

for line in f3:
    words = line.split()
    just_words = [x for x in words if x != "|"]
    dict3_complete[just_words[1]] = just_words[2:]

f3.close()

# %%
f =  open('labelled-tokens.txt', encoding='latin-1')
f1 = open('dict.txt')
f2 = open('emnlp_dict.txt')

# dictionary look up for IV words
dict1 = []
for line in f1:
    words = line.split()
    dict1.append(words[0])
    
    
keys=[]
values=[]
for line in f2:
    words = line.split()
    keys.append(words[0])
    if len(words) == 2:
        values.append(words[1])
    else:
        values.append(" ".join(words[1:]))
    
dict2 = dict(zip(keys,values))


OOV_tokens=[]
correct=[]
for line in f:
    words = line.split()
    if words[1] != 'IV' and words[1] != 'NO':
        OOV_tokens.append(words[0])
        correct.append(words[2])
    

f.close()
f1.close()
f2.close()

# %%
f4 = open('w5_.txt')

w5 = []

for line in f4:
    item = line.split()
    w5.append(item[1]+item[2]+item[3]+item[4]+item[5])
    
f4.close()

# %%
unlabelled =  open('unlabelled-tokens.txt', 'r', encoding='latin-1')
# list of unlabelled tokens
unlabelled_tokens = []
for line in unlabelled:
    words = line.split()
    unlabelled_tokens.append(words[0])

normalisation = []

for index, item in enumerate(unlabelled_tokens):
    if re.match('^.*[:/_&%@#~<=>`",;\'\-\.\!\$\s\?\+\*\^\|\[\]\(\)\{\}]+.*$', item):
        normalisation.append(item)
        
    elif item in dict3:
        normalisation.append(dict3[item])
        
    elif item in labelled_tokens:
        normalisation.append(labelled_tokens[item])
        
    elif item in dict2:
        normalisation.append(dict2[item])
        
    elif item in dict1:
        normalisation.append(item)
        
    else:
        wordlist = []
        if item in dict3_complete:
            if len(dict3_complete[item]) == 1:
                normalisation.append(item)
                continue
            else:
                wordlist.extend(dict3_complete[item])
        
        peter = correction(item)
        wordlist.extend(soundex_filter(item, levenshtein_distance(item, dict1)))
        
        if peter in wordlist:
            normalisation.append(peter)
            continue
        else:
            wordlist.append(peter)
            wordlist.extend(spellChecking(item))
            
            if unlabelled_tokens[index-1]  in dict1 and unlabelled_tokens[index+1]  in dict1:
                freq = {}
                for word in wordlist:
                    r = re.compile(".*%s%s%s.*" % (unlabelled_tokens[index-1], word, unlabelled_tokens[index+1]))
                    newlist = filter(r.match, w5)
                    freq[word] = len(list(newlist)) 
                normalisation.append(max(freq.keys(), key=(lambda k: freq[k])))
                continue
            else:
                fdist = nltk.FreqDist(wordlist) 
                normalisation.append(fdist.max())
                continue
        
normalisation

# %% [markdown]
# ### Best Accuracy Score

# %%
unlabelled =  open('unlabelled-tokens.txt', 'r', encoding='latin-1')
unlabelled_tokens = []
for line in unlabelled:
    words = line.split()
    unlabelled_tokens.append(words[0])

normalisation = []

for index, item in enumerate(unlabelled_tokens):
    if re.match('^.*[:/_&%@#~<=>`",;\.\!\$\s\?\+\*\^\|\[\]\(\)\{\}]+.*$', item):
        normalisation.append(item)
        
    elif item in dict3:
        normalisation.append(dict3[item])
        
    elif item in labelled_tokens:
        normalisation.append(labelled_tokens[item])
        
    elif item in dict2:
        normalisation.append(dict2[item])
        
    elif item in dict1:
        normalisation.append(item)
        
    elif tag[item][0] in ["N","!","^","Z","E","~","$","A","V","G","R","L"]:
        normalisation.append(item)
    
    else:
        wordlist = spellChecking(item)
        
        if item in dict3_complete:
            wordlist.extend(dict3_complete[item])
        
        wordlist.extend(soundex_filter(item, levenshtein_distance(item, dict1)))
                
        fdist = nltk.FreqDist(wordlist) 
        
        normalisation.append(fdist.max())
        
normalisation
# Out:
# ['rt',
#  '@teddyferrari1',
#  'ah',
#  '@datzmenoni',
#  'why',
#  'sub',
#  'ozil',
#  '@lexzydoo_ab',
#  'opolo',
#  'eyes',
#  'you',
#  'no',
#  'fit',
#  'open',
#  'eyes',
#  'you',
#  'have',
#  'a',
#  'very',
#  'sexy',
#  'header',
#  '@jaibrooks1',
#  'roar',
#  'i',
#  'miss',
#  'you',
#  'my',
#  'bie',
#  'where',
#  'you',
#  'wanna',
#  'out',
#  'with',
#  'me',
#  'have',
#  'a',
#  'wonderful',
#  'day',
#  'like',
#  'a',
#  'swan',
#  'day',
#  'haha',
#  'cantik',
#  'rt',
#  '@historyinpics',
#  'julie',
#  'christie',
#  'photograph',
#  'by',
#  'richard',
#  'avedon',
#  'http://t.co/gscav8o0ik',
#  'rt',
#  '@fvckxhemmings',
#  'did',
#  'calum',
#  'slip',
#  'omfg',
#  '@daviddarkshade',
#  'and',
#  'you',
#  "didn't",
#  'make',
#  'this',
#  'brother',
#  'my',
#  'friend',
#  'jack',
#  'storm',
#  'did',
#  '@xoxoxyareli',
#  '@billmillerprobz',
#  'pshh',
#  'i',
#  'went',
#  'and',
#  'got',
#  'mine',
#  'done',
#  'regardless',
#  "i'm",
#  'sick',
#  'of',
#  'not',
#  'being',
#  'able',
#  'to',
#  'be',
#  'a',
#  'girl',
#  'haha',
#  '@tindency',
#  'syempre',
#  'in',
#  'the',
#  'right',
#  'age',
#  'haha',
#  '@khalilbrown_',
#  'shit',
#  'rocking',
#  'go',
#  'head',
#  'show',
#  'that',
#  'to',
#  'bria',
#  'rt',
#  '@kpoplover727',
#  'words',
#  'that',
#  'describe',
#  'exo',
#  'luhan',
#  'is',
#  'pain',
#  'chanyeol',
#  'is',
#  'sex',
#  'sehun',
#  'is',
#  'porn',
#  'rt',
#  '@michael_heaver',
#  'UK independence party',
#  'has',
#  'had',
#  'two',
#  'councillors',
#  'elected',
#  'in',
#  'northern',
#  'ireland',
#  'today',
#  'marvelous',
#  '@kam_maynee',
#  'lol',
#  'because',
#  'i',
#  'said',
#  'you',
#  'would',
#  'been',
#  'falling',
#  'right',
#  'along',
#  'with',
#  'me',
#  '@raqueldiosdado',
#  'yeah',
#  'i',
#  'was',
#  'gonna',
#  'hit',
#  'you',
#  'up',
#  'but',
#  'guess',
#  'not',
#  'lol',
#  '@_nicolebeans',
#  'haha',
#  'okay',
#  'well',
#  'at',
#  'least',
#  'i',
#  'know',
#  'the',
#  'other',
#  'blog',
#  "you've",
#  'been',
#  'dying',
#  'to',
#  'hide',
#  'lol',
#  'he',
#  'obviously',
#  "doesn't",
#  'understand',
#  'that',
#  '#ballislife',
#  'http://t.co/wbx9h8jndm',
#  '@_queencliffordx',
#  "i'm",
#  'friends',
#  'with',
#  'grecia',
#  'i',
#  'know',
#  'this',
#  '@iisuperwomanii',
#  'i',
#  'just',
#  'love',
#  'the',
#  'way',
#  'you',
#  'are',
#  'your',
#  'fun',
#  'personality',
#  'and',
#  'how',
#  'you',
#  'arent',
#  'afraid',
#  'to',
#  'express',
#  'yourself',
#  'so',
#  'openly',
#  'on',
#  'youtube',
#  '#amazon',
#  'usa',
#  'spalding',
#  'nba',
#  'street',
#  '#basketball',
#  'by',
#  'spalding',
#  'http://t.co/eybuqyi0ms',
#  '@graemeforsyth',
#  'haha',
#  "i'm",
#  'ony',
#  'doing',
#  'this',
#  'to',
#  'piss',
#  'off',
#  'everyone',
#  'on',
#  'my',
#  'tl',
#  'rt',
#  '@sebyul',
#  'haru',
#  'hana',
#  'q',
#  'something',
#  'you',
#  "can't",
#  'do',
#  'despite',
#  'being',
#  'the',
#  'golden',
#  'maknae',
#  'jeongguk',
#  'i',
#  "can't",
#  'talk',
#  'and',
#  'studying',
#  'laughs',
#  'dremel',
#  'sm844',
#  'crown',
#  'molding',
#  'guide',
#  'dremel',
#  'sm844',
#  'crown',
#  'molding',
#  'guide',
#  'by',
#  'dremel',
#  '1)buy',
#  'new',
#  'http://t.co/jlixvido8d',
#  'conor',
#  'keelan',
#  'ff',
#  'polling',
#  'sixth',
#  'with',
#  'first',
#  'preference',
#  'votes',
#  'in',
#  'dundalk-carlingford',
#  '#le14',
#  '#louth',
#  'rt',
#  '@plssmalik',
#  '#1dnewsongiwillsurvive',
#  'eu',
#  'amo',
#  'vcs',
#  'eu',
#  'amo',
#  'esse',
#  'fandom',
#  'mim',
#  'beiji',
#  'directionas',
#  'investissement',
#  'a',
#  'cape',
#  'coral',
#  'murs',
#  'chinois',
#  'chinese',
#  'drywall',
#  'http://t.co/ffsbrpb2x3',
#  'via',
#  '@youtube',
#  '@creatiinggfx',
#  '@scorestreakshq1',
#  'alright',
#  'like',
#  'of',
#  'what',
#  'nigga',
#  '@jpaulinel',
#  'heheheh',
#  'miss',
#  'you',
#  'ate',
#  'jean',
#  'you',
#  'got',
#  'me',
#  'feeling',
#  'brand',
#  'new',
#  'wolfnsheepclothing140',
#  'http://t.co/azde27cbhd',
#  'rt',
#  '@dxoxoluhandeer',
#  "i'm",
#  'eating',
#  'cadbury',
#  'right',
#  'now',
#  'haha',
#  'xd',
#  'galeris',
#  'usa',
#  'a',
#  'tag',
#  'and',
#  'custa',
#  'and',
#  '#wmajustinbieber',
#  'rt',
#  '@mentalbreakdawn',
#  'taeminho',
#  'lighstick',
#  'has',
#  'arrived',
#  'thanku',
#  '@2minshipperindo',
#  '@tmncy95',
#  '@minflames',
#  'http://t.co/h031oliqsv',
#  '@imgooby',
#  'zoom',
#  'in',
#  'see',
#  'an',
#  'sekret',
#  'message',
#  'http://t.co/wahejeh987',
#  '@emilydavison196',
#  '@carolinemckiben',
#  'you',
#  'will',
#  'appreciate',
#  'this',
#  '#urafegit',
#  'you',
#  'know',
#  'that',
#  'that',
#  "ain't",
#  'a',
#  'bad',
#  'bitch',
#  "that's",
#  'a',
#  'knock',
#  'off',
#  '#job',
#  '#omaha',
#  'receptionist',
#  'florence',
#  'clinic',
#  'feet',
#  'omaha',
#  'alegent',
#  'creighton',
#  'health',
#  'is',
#  'the',
#  'largest',
#  'not-for-profit',
#  'fai',
#  'http://t.co/2mehl04rr8',
#  'srk',
#  'with',
#  'salmann',
#  'khann',
#  'auchhh',
#  'shoo',
#  'handsome',
#  'southbound',
#  'between',
#  'a47',
#  'near',
#  'hinckley',
#  'west',
#  'and',
#  'a47',
#  'near',
#  'hinckley',
#  'east',
#  'so',
#  'so',
#  'on',
#  'the',
#  'a5',
#  'from',
#  'cannock',
#  'towards',
#  'har-',
#  'http://t.co/xcwo5xdivj',
#  'rt',
#  '@1dalert',
#  'guys',
#  'that',
#  'picture',
#  'of',
#  'zayn',
#  'is',
#  'old',
#  'and',
#  'also',
#  'you',
#  'can',
#  'see',
#  'niall',
#  'standing',
#  'next',
#  'to',
#  'him',
#  'like',
#  'he',
#  "wouldn't",
#  'be',
#  'in',
#  'the',
#  'crowd',
#  'haha',
#  "i'm",
#  'in',
#  'a',
#  'good',
#  'mood',
#  'right',
#  'now',
#  'just',
#  'because',
#  'this',
#  'music',
#  'lol',
#  'rt',
#  '@fanzorro',
#  'wait',
#  'how',
#  'infact',
#  'why',
#  'do',
#  'you',
#  'know',
#  'this',
#  'rt',
#  '@yung_btee',
#  'most',
#  'zulu',
#  'nikkas',
#  'got',
#  'fore',
#  'skin',
#  'and',
#  'they',
#  'smell',
#  'rt',
#  '@_1dslovakia',
#  '#new',
#  'niall',
#  'on',
#  'stage',
#  'at',
#  'croke',
#  'park',
#  'dublin',
#  'http://t.co/ejy8zdiui8',
#  'rt',
#  '@horantitties',
#  'harrys',
#  'reaction',
#  'when',
#  'they',
#  'let',
#  'him',
#  'play',
#  "he's",
#  'so',
#  'cute',
#  'omg',
#  '#teamniall',
#  'http://t.co/cljucr0rrh',
#  'they',
#  'expect',
#  'me',
#  'to',
#  'drive',
#  'to',
#  'california',
#  'for',
#  'court',
#  'just',
#  'for',
#  'a',
#  'back',
#  'seatbelt',
#  'ticket',
#  'fuhh',
#  'that',
#  '@vilde_hr',
#  'i',
#  'literally',
#  'love',
#  'you',
#  'omfg',
#  'you',
#  'just',
#  'made',
#  'my',
#  'whole',
#  'day',
#  'complete',
#  'g',
#  "i'll",
#  'stay',
#  'home',
#  'before',
#  'i',
#  'go',
#  'to',
#  'a',
#  'party',
#  'in',
#  'be',
#  'with',
#  'a',
#  'bunch',
#  'of',
#  'fake',
#  'mtfs',
#  'or',
#  '0h',
#  'he',
#  'pss',
#  'cbs',
#  'pss',
#  'end',
#  'first',
#  'recap',
#  'http://t.co/qkkmsjop1o',
#  '@arse2mouse',
#  'their',
#  'number',
#  '8(cb',
#  'havard',
#  'nordtveit',
#  'was',
#  'an',
#  'arsenal',
#  'youth',
#  'reserve',
#  'player',
#  'lol',
#  'rt',
#  '@bbcsporf',
#  'exclusive',
#  'footage',
#  'of',
#  'vincent',
#  'company',
#  'going',
#  'up',
#  'to',
#  'yaya',
#  'toure',
#  'after',
#  'telling',
#  'him',
#  'he',
#  'was',
#  'leaving',
#  'https://t.co/wxa0klstoh',
#  'now',
#  'streaming',
#  'shakira',
#  'feat',
#  'residence',
#  'of',
#  'calle',
#  'gordita',
#  'on',
#  'http://t.co/a2v5jttvzj',
#  "ct/ma's",
#  'nightlife',
#  'website',
#  '@safiasharif_xox',
#  'wtf',
#  "i've",
#  'only',
#  'just',
#  'seen',
#  'this',
#  'omg',
#  'weaver',
#  'has',
#  'more',
#  'blocks',
#  'than',
#  'lundquist',
#  'has',
#  'saves',
#  'ha',
#  'love',
#  'rds',
#  'john',
#  'mayer',
#  'hugs and kisses',
#  'beyonce',
#  'cover',
#  'new',
#  'music',
#  'http://t.co/dpwsakocj2',
#  'adore',
#  'you',
#  'remix',
#  'miley',
#  'cyrus',
#  'cedric',
#  'gervais',
#  'rt',
#  '@bootygangcult',
#  'mom',
#  "let's",
#  'watch',
#  'blues',
#  'clues',
#  'son',
#  'you',
#  'going',
#  'have',
#  'to',
#  'kill',
#  'me',
#  'first',
#  'http://t.co/pwarsyqezv',
#  'rt',
#  '@jason_om',
#  'poll',
#  'which',
#  'would',
#  'you',
#  'cut',
#  '@qanda',
#  'v',
#  'peppa',
#  'pig',
#  'via',
#  '@theheraldsun',
#  '#auspol',
#  '#abc',
#  'http://t.co/chaadb09aq',
#  'eeak',
#  'meen',
#  'lyshaa',
#  ':d',
#  'rt',
#  '@alyshays',
#  'keep',
#  'save',
#  'this',
#  'relationship',
#  'seeing',
#  'oll',
#  'friend',
#  'again',
#  'was',
#  "good'o",
#  'rt',
#  '@5sos_daily',
#  'luke',
#  'today',
#  'via',
#  'kylie',
#  'g',
#  'stylist',
#  'http://t.co/5glsteqxcf',
#  'rt',
#  '@lyeolnam',
#  'please',
#  'rt',
#  'have',
#  'sungjong',
#  'last',
#  'romeo',
#  'card',
#  'want',
#  'seongyeol',
#  'or',
#  'myungsoo',
#  'card',
#  'sg',
#  'only',
#  'rt',
#  '@hemmings_taco',
#  'rt',
#  'for',
#  'a',
#  'deathmatch',
#  'to',
#  'luke',
#  'hemmings',
#  'mbf',
#  'because',
#  'i',
#  'actually',
#  'do',
#  'them',
#  'http://t.co/pvxsqk1cva',
#  '@pragarassongs',
#  'christian',
#  'pace',
#  'part',
#  'amore',
#  'hello',
#  'vinto',
#  'tu',
#  '#amici13',
#  'http://t.co/nviyl66x8m',
#  '@markennis',
#  'dan',
#  'is',
#  'a',
#  'kcu',
#  'alum',
#  'has',
#  'other',
#  'funny',
#  'songs',
#  'like',
#  'this',
#  'calls',
#  'himself',
#  'whiteboy',
#  'dj',
#  'lol',
#  '@miketokes',
#  'sorry',
#  'about',
#  'the',
#  'wait',
#  'home',
#  'but',
#  'check',
#  'your',
#  'direct message',
#  'when',
#  'you',
#  'get',
#  'the',
#  'chance',
#  'guess',
#  'who',
#  "i'm",
#  'cosplaying',
#  "it's",
#  'shit',
#  'but',
#  'still',
#  'as',
#  'at',
#  'comic',
#  '@tt_shake',
#  'or',
#  'you',
#  'can',
#  'just',
#  'wear',
#  'a',
#  'condom',
#  'and',
#  'you',
#  "don't",
#  'have',
#  'to',
#  'worry',
#  'about',
#  'pulling',
#  'out',
#  '@mika90628',
#  'woah',
#  'i',
#  'know',
#  'this',
#  'song',
#  'oppa',
#  'one',
#  'of',
#  'my',
#  'favorite',
#  'songs',
#  'asu',
#  'wa',
#  'kuru',
#  'kara',
#  '@ashley_twt',
#  'jimin',
#  'is',
#  'it',
#  'okay',
#  'if',
#  'i',
#  'asked',
#  'for',
#  'angpaos',
#  'jungkook',
#  'does',
#  'this',
#  'look',
#  'make',
#  'aunt',
#  'and',
#  'uncle',
#  'happy',
#  'for',
#  'bigger',
#  'angpao',
#  'alpukat',
#  'madu',
#  'yummy',
#  'manis',
#  'banget',
#  'i',
#  'like',
#  'this',
#  'to',
#  'wrap',
#  'up',
#  'our',
#  'month',
#  'of',
#  'moscato',
#  'host',
#  'a',
#  'moscato',
#  'tasting',
#  'party',
#  '#socialhour',
#  'http://t.co/gd2czn6cki',
#  'http://t.co/yonfydyojb',
#  '@minquannn',
#  'haha',
#  'mq',
#  'please',
#  'as',
#  'easy',
#  'as',
#  'doto',
#  'for',
#  'me',
#  '#feedforlife',
#  'rt',
#  '@greatamerrest',
#  'now',
#  'on',
#  'tap',
#  '@sweetwater_gar',
#  'centreville',
#  'chipotle',
#  'porter',
#  'rt',
#  '@thevampsrob',
#  "y'all",
#  'so',
#  'worried',
#  'about',
#  'the',
#  'fact',
#  'zayn',
#  'was',
#  'smoking',
#  'weed',
#  'he',
#  "wasn't",
#  'even',
#  'wearing',
#  'a',
#  'seat',
#  'belt',
#  'rt',
#  '@bhadoosky',
#  'eminado',
#  'means',
#  'goodluck',
#  'surulere',
#  'means',
#  'patience',
#  '@donjazzy',
#  'must',
#  'be',
#  'related',
#  'to',
#  'our',
#  'president',
#  'rt',
#  '@worldstarfunny',
#  'this',
#  'little',
#  'nigga',
#  'did',
#  'years',
#  'in',
#  'timeout',
#  'http://t.co/bswqzqespg',
#  'omg',
#  'this',
#  'mango',
#  'is',
#  'some',
#  'fucking',
#  'kill',
#  'real',
#  'bjp',
#  'supporters',
#  'would',
#  'be',
#  'delighted',
#  'https://t.co/k06cqv8mqc',
#  'shourie',
#  'ji',
#  'putting',
#  '@swapan55',
#  'in',
#  'his',
#  'place',
#  '@sarkar_swati',
#  '@sandeepweb',
#  '@lisyopenmind',
#  '@potteralda',
#  '@purrlcat',
#  'angry',
#  'knows',
#  "she's",
#  'met',
#  'my',
#  'jake',
#  'a',
#  'badboy',
#  'with',
#  'a',
#  'temper',
#  'raaaaar',
#  'i',
#  'just',
#  'got',
#  'sugar',
#  'daddies',
#  'online',
#  '-me',
#  'you',
#  'go',
#  'girl',
#  '-dad',
#  'rt',
#  '@bradieboolove',
#  'this',
#  'graduation',
#  'rehearsal',
#  'is',
#  'taking',
#  'forever',
#  'thank',
#  'goodness',
#  "i'm",
#  'textin',
#  '@onlyonesnacks',
#  ...]

# %% [markdown]
# ### Write to txt for submission

# %%
# write to file 
kaggle = open('kaggle.txt','w')
kaggle.write('Token,Prediction' + '\n')
i=1
for line in normalisation:
    kaggle.write(str(i) + ',' + line + '\n')
    i=i+1
    
kaggle.close()

# %% [markdown]
# ### Evaluation metrics
# ---
# ** Accuracy **

# %%
def accuracy(actual, prediction):
    i = 0
    for x,y in zip(actual, prediction):
        if x == y:
            i = i + 1
    return i/len(actual)

# %%
fdist = nltk.FreqDist([x[1] for x in dontknow]) 
import operator
sorted_x = sorted(fdist.items(), key=operator.itemgetter(1),reverse=True)
sorted_x
# Out:
# [('exo', 31),
#  ('zayn', 23),
#  ('cr', 22),
#  ('vs', 19),
#  ('tbh', 16),
#  ('ive', 16),
#  ('snapchat', 16),
#  ('idc', 15),
#  ('playing', 15),
#  ('selfie', 15),
#  ('luhan', 13),
#  ('sehun', 13),
#  ('croke', 13),
#  ('chanyeol', 12),
#  ('desain', 12),
#  ('followers', 12),
#  ('ng', 11),
#  ('jfb', 11),
#  ('suho', 11),
#  ('lmaoo', 11),
#  ('ukip', 10),
#  ('lebron', 10),
#  ('shenanigans', 10),
#  ('harrystyles', 10),
#  ('kamar', 10),
#  ('ang', 10),
#  ('psg', 9),
#  ('ilysm', 9),
#  ('mixtape', 9),
#  ('tf', 9),
#  ('playlist', 9),
#  ('rn', 9),
#  ('kik', 9),
#  ('selfies', 8),
#  ('ideas', 8),
#  ('kardashian', 8),
#  ('malaysia', 8),
#  ('boko', 8),
#  ('haram', 8),
#  ('instagram', 8),
#  ('5sos', 8),
#  ('shinee', 8),
#  ('xo', 7),
#  ('miley', 7),
#  ('hemmings', 7),
#  ('anak', 7),
#  ('ke', 7),
#  ('ronaldo', 7),
#  ('modi', 7),
#  ('ily', 7),
#  ('3rd', 7),
#  ('started', 7),
#  ('iggy', 7),
#  ('zouis', 7),
#  ('wanted', 7),
#  ('calum', 6),
#  ('usa', 6),
#  ('voted', 6),
#  ('hashtag', 6),
#  ('yg', 6),
#  ('hq', 6),
#  ('cewek', 6),
#  ('avi', 6),
#  ('rey', 6),
#  ('seoul', 6),
#  ('thots', 6),
#  ('efron', 6),
#  ('ig', 6),
#  ('chelsea', 6),
#  ('dia', 6),
#  ('finals', 6),
#  ('snsd', 6),
#  ('xmen', 6),
#  ('eyes', 5),
#  ('amo', 5),
#  ('toure', 5),
#  ('songs', 5),
#  ('dms', 5),
#  ('asked', 5),
#  ('pokemon', 5),
#  ('lls', 5),
#  ('texting', 5),
#  ('tears', 5),
#  ('perrie', 5),
#  ('followback', 5),
#  ('itu', 5),
#  ('pm', 5),
#  ('ahhh', 5),
#  ('taemin', 5),
#  ('exoplanet', 5),
#  ('hahahah', 5),
#  ('nawaz', 5),
#  ('likes', 5),
#  ('lovato', 5),
#  ('kpop', 5),
#  ('buat', 5),
#  ('mbc', 5),
#  ('futsal', 5),
#  ('mj', 5),
#  ('minaj', 5),
#  ('kobe', 5),
#  ('london', 5),
#  ('fantaken', 5),
#  ('youre', 5),
#  ('beats', 5),
#  ('dublin', 4),
#  ('liam', 4),
#  ('catz', 4),
#  ('pc', 4),
#  ('juseyo', 4),
#  ("we're", 4),
#  ('kings', 4),
#  ('watson', 4),
#  ('openfollow', 4),
#  ('kpopers', 4),
#  ('ryan', 4),
#  ('lagi', 4),
#  ('ap', 4),
#  ('dr', 4),
#  ("you'll", 4),
#  ('comments', 4),
#  ('lolz', 4),
#  ('smtown', 4),
#  ('wth', 4),
#  ('donghae', 4),
#  ('baekhyun', 4),
#  ('cek', 4),
#  ('vixx', 4),
#  ('darragh', 4),
#  ('sharif', 4),
#  ('frfr', 4),
#  ('tomlinson', 4),
#  ('beasiswa', 4),
#  ('farage', 4),
#  ('uae', 4),
#  ('luiz', 4),
#  ('ibaka', 4),
#  ('usernames', 4),
#  ('tweep', 4),
#  ('jai', 4),
#  ('livestream', 4),
#  ('oomf', 4),
#  ('kau', 4),
#  ('mep', 4),
#  ('sakit', 4),
#  ('mm', 4),
#  ('ty', 4),
#  ('wwa', 4),
#  ('yuri', 4),
#  ('taeyeon', 4),
#  ('hurts', 4),
#  ('tepatin', 4),
#  ('wkwk', 4),
#  ('bouta', 4),
#  ('nighas', 4),
#  ('idr', 4),
#  ('mayweather', 4),
#  ('mei', 4),
#  ('jongin', 4),
#  ('yixing', 4),
#  ('wizkid', 4),
#  ('hari', 4),
#  ('worldwide', 4),
#  ('justunfollow', 4),
#  ('talaga', 4),
#  ('ik', 4),
#  ('ulit', 4),
#  ('camila', 4),
#  ('500px', 4),
#  ('htc', 4),
#  ('beaut', 4),
#  ('jokes', 4),
#  ('seniors', 4),
#  ('porn', 3),
#  ('elected', 3),
#  ("you've", 3),
#  ('dremel', 3),
#  ('votes', 3),
#  ('harrys', 3),
#  ('beyonce', 3),
#  ('bjp', 3),
#  ('johnson', 3),
#  ('momma', 3),
#  ('pacquiao', 3),
#  ('tweetin', 3),
#  ('fasta', 3),
#  ('idgaf', 3),
#  ('ellie', 3),
#  ('photoset', 3),
#  ('tw', 3),
#  ('dumbass', 3),
#  ('asap', 3),
#  ('xxx', 3),
#  ('ngayon', 3),
#  ('hehehe', 3),
#  ('download', 3),
#  ('tells', 3),
#  ('commented', 3),
#  ('dreams', 3),
#  ('wmf', 3),
#  ('hyun', 3),
#  ("girl's", 3),
#  ('nk', 3),
#  ('whatsapp', 3),
#  ('reasons', 3),
#  ('wins', 3),
#  ('hmu', 3),
#  ('messages', 3),
#  ('lyrics', 3),
#  ('nada', 3),
#  ('siwon', 3),
#  ('nike', 3),
#  ('wala', 3),
#  ('loh', 3),
#  ('mc', 3),
#  ('uefa', 3),
#  ('champions', 3),
#  ('macbook', 3),
#  ("isn't", 3),
#  ('kidding', 3),
#  ('ofc', 3),
#  ("hasn't", 3),
#  ('problems', 3),
#  ('facetime', 3),
#  ('nakheel', 3),
#  ('mtn', 3),
#  ('drums', 3),
#  ('nomore', 3),
#  ('dodgers', 3),
#  ('mlb', 3),
#  ('nialls', 3),
#  ('destroyed', 3),
#  ('scores', 3),
#  ('ughh', 3),
#  ('results', 3),
#  ('zuma', 3),
#  ('nflpa', 3),
#  ('goodell', 3),
#  ('awwww', 3),
#  ('played', 3),
#  ('ini', 3),
#  ('xabi', 3),
#  ('mfs', 3),
#  ('lucu', 3),
#  ('narry', 3),
#  ('takes', 3),
#  ('sana', 3),
#  ('hardwell', 3),
#  ('mentions', 3),
#  ('fanbase', 3),
#  ('tayo', 3),
#  ('lololol', 3),
#  ('edwards', 3),
#  ('pissed', 3),
#  ('whatchu', 3),
#  ('pictures', 3),
#  ('brothers', 3),
#  ('sj', 3),
#  ('yeon', 3),
#  ('emoji', 3),
#  ('hahahahaha', 3),
#  ('trans', 3),
#  ('habs', 3),
#  ('bffs', 3),
#  ('soff', 3),
#  ('mata', 3),
#  ('fxck', 3),
#  ('favorited', 3),
#  ('sbs', 3),
#  ('gua', 3),
#  ('tak', 3),
#  ('puso', 3),
#  ('minho', 3),
#  ('sms', 3),
#  ('qpr', 3),
#  ('scrolling', 3),
#  ('campaigns', 3),
#  ('pre', 3),
#  ('boutta', 3),
#  ('reached', 3),
#  ('lets', 3),
#  ('liverpool', 3),
#  ('apink', 3),
#  ('craic', 3),
#  ('xiumin', 3),
#  ('lakers', 3),
#  ('djokovic', 3),
#  ('nuh', 3),
#  ('jonghyun', 3),
#  ('tottenham', 3),
#  ('fc', 3),
#  ('ctfu', 3),
#  ("who's", 3),
#  ('rangers', 3),
#  ('koraa', 3),
#  ('leedle', 3),
#  ('2ne1', 3),
#  ('dd', 3),
#  ('hd', 3),
#  ("aren't", 3),
#  ('o-o', 3),
#  ('vegas', 3),
#  ('27th', 3),
#  ('diaz', 3),
#  ('perf', 3),
#  ('byrne', 3),
#  ('mariah', 3),
#  ('carey', 3),
#  ('smth', 3),
#  ('pq', 3),
#  ('khloe', 3),
#  ('tesco', 3),
#  ('retweeting', 3),
#  ('britax', 3),
#  ('taiwan', 3),
#  ('cafe', 3),
#  ('artists', 3),
#  ('rw', 3),
#  ('hits', 3),
#  ('france', 3),
#  ('meth', 3),
#  ('kearny', 3),
#  ('bria', 2),
#  ('ireland', 2),
#  ('nba', 2),
#  ('haru', 2),
#  ('studying', 2),
#  ('laughs', 2),
#  ('sm844', 2),
#  ('vcs', 2),
#  ('esse', 2),
#  ('largest', 2),
#  ('a47', 2),
#  ('hinckley', 2),
#  ('infact', 2),
#  ('pss', 2),
#  ('shakira', 2),
#  ('kylie', 2),
#  ('mbf', 2),
#  ('woah', 2),
#  ('moscato', 2),
#  ('chipotle', 2),
#  ('spirite', 2),
#  ('ponning', 2),
#  ('hahhahaha', 2),
#  ('benitez', 2),
#  ('napoli', 2),
#  ('rahway', 2),
#  ('nj', 2),
#  ('paramedic', 2),
#  ('worries', 2),
#  ('children', 2),
#  ('mt', 2),
#  ('marries', 2),
#  ('pasta', 2),
#  ('toilets', 2),
#  ('characters', 2),
#  ('nico', 2),
#  ('goulding', 2),
#  ('pains', 2),
#  ('selangor', 2),
#  ('mookie', 2),
#  ('shots', 2),
#  ('performing', 2),
#  ('bgt', 2),
#  ('scaramouche', 2),
#  ('xolo', 2),
#  ('lfc', 2),
#  ('lowkey', 2),
#  ('dropped', 2),
#  ('asses', 2),
#  ('arigatou', 2),
#  ('zuccarello', 2),
#  ('moto', 2),
#  ('kakak', 2),
#  ('mp4-12c', 2),
#  ('chinx', 2),
#  ('drugz', 2),
#  ('camo', 2),
#  ('events', 2),
#  ("they've", 2),
#  ('released', 2),
#  ('fosho', 2),
#  ('mph', 2),
#  ('nne', 2),
#  ('sheeran', 2),
#  ('fanclub', 2),
#  ('corvo', 2),
#  ("day's", 2),
#  ('theatre', 2),
#  ('esta', 2),
#  ('styles', 2),
#  ('stp', 2),
#  ('busan', 2),
#  ('vows', 2),
#  ('ties', 2),
#  ('ibnlive', 2),
#  ('signing', 2),
#  ('hashtags', 2),
#  ('bahahaha', 2),
#  ('ends', 2),
#  ('angelou', 2),
#  ('vimeo', 2),
#  ('steps', 2),
#  ('spain', 2),
#  ('tmh', 2),
#  ('kkk', 2),
#  ('bafana', 2),
#  ('aap', 2),
#  ('senpai', 2),
#  ('durk', 2),
#  ('tbt', 2),
#  ('sheikh', 2),
#  ('hasina', 2),
#  ('returns', 2),
#  ("dm's", 2),
#  ('rao', 2),
#  ('screamed', 2),
#  ('weights', 2),
#  ('sakta', 2),
#  ('attending', 2),
#  ('swearing-in', 2),
#  ('nao', 2),
#  ('nokia', 2),
#  ('sushmita', 2),
#  ('bernardino', 2),
#  ('yunho', 2),
#  ('gwyn', 2),
#  ('awks', 2),
#  ('weh', 2),
#  ('beliebers', 2),
#  ('puerto', 2),
#  ('breh', 2),
#  ('samaha', 2),
#  ('rakim', 2),
#  ('hahahahahaha', 2),
#  ('aed', 2),
#  ('icymi', 2),
#  ('wwe', 2),
#  ('janoskians', 2),
#  ('rides', 2),
#  ('forreal', 2),
#  ('utk', 2),
#  ('musicians', 2),
#  ('wkwkw', 2),
#  ('pitbull', 2),
#  ('brixham', 2),
#  ('28th', 2),
#  ('goodmorning', 2),
#  ('9am', 2),
#  ('aeg', 2),
#  ('fangirl', 2),
#  ('gomes', 2),
#  ('points', 2),
#  ('seasonings', 2),
#  ('dungey', 2),
#  ('dosent', 2),
#  ('prev', 2),
#  ('yey', 2),
#  ('yoon', 2),
#  ('secrets', 2),
#  ('wizards', 2),
#  ("you'd", 2),
#  ('inbox', 2),
#  ('releases', 2),
#  ('lmaooo', 2),
#  ('niam', 2),
#  ('grabe', 2),
#  ('todays', 2),
#  ('mashup', 2),
#  ('promoting', 2),
#  ('stronger', 2),
#  ('ngl', 2),
#  ('libre', 2),
#  ('ohmygod', 2),
#  ('hands', 2),
#  ('bhi', 2),
#  ('stoked', 2),
#  ('neco', 2),
#  ('slapped', 2),
#  ('cakep', 2),
#  ('kawan', 2),
#  ('monkeys', 2),
#  ('finsbury', 2),
#  ('mnl', 2),
#  ('olha', 2),
#  ('views', 2),
#  ('mehraj', 2),
#  ('ibadat', 2),
#  ('answered', 2),
#  ('posts', 2),
#  ('rumah', 2),
#  ('changed', 2),
#  ('rolls', 2),
#  ('videos', 2),
#  ('spotify', 2),
#  ('von', 2),
#  ('girlfriend', 2),
#  ('krispy', 2),
#  ('kreme', 2),
#  ('macklemore', 2),
#  ('dapat', 2),
#  ('africa', 2),
#  ('parties', 2),
#  ('foh', 2),
#  ('tysm', 2),
#  ('dieing', 2),
#  ("shinee's", 2),
#  ("exo's", 2),
#  ('sekalian', 2),
#  ('siapa', 2),
#  ('kita', 2),
#  ('inf', 2),
#  ('responds', 2),
#  ('imessage', 2),
#  ('delivers', 2),
#  ('sukhwinder', 2),
#  ('chaiyya', 2),
#  ('pills', 2),
#  ('potions', 2),
#  ('horan', 2),
#  ('barbie', 2),
#  ('isra', 2),
#  ('swerving', 2),
#  ('cars', 2),
#  ('deserves', 2),
#  ('sox', 2),
#  ('kst', 2),
#  ('oomfs', 2),
#  ('idiots', 2),
#  ('fancam', 2),
#  ('kyungsoo', 2),
#  ('dyo', 2),
#  ('addis', 2),
#  ('tickets', 2),
#  ('ayebody', 2),
#  ('cities', 2),
#  ('cancelling', 2),
#  ('headphones', 2),
#  ('cinta', 2),
#  ('bagi', 2),
#  ('juwita', 2),
#  ('rell', 2),
#  ('ol', 2),
#  ('cakes', 2),
#  ('starbucks', 2),
#  ('cookies', 2),
#  ('nutella', 2),
#  ('wears', 2),
#  ('juni', 2),
#  ('garfield', 2),
#  ('ph', 2),
#  ('yuk', 2),
#  ('defo', 2),
#  ('sb', 2),
#  ('tenshi', 2),
#  ('lastnight', 2),
#  ('kfc', 2),
#  ('began', 2),
#  ('jen', 2),
#  ('aegyo', 2),
#  ('salah', 2),
#  ('nigeria', 2),
#  ('shaquille', 2),
#  ('np', 2),
#  ('rmx', 2),
#  ('naija', 2),
#  ('noticed', 2),
#  ('scientists', 2),
#  ('teleportation', 2),
#  ('subtweeting', 2),
#  ('internet', 2),
#  ('wuddup', 2),
#  ('nonton', 2),
#  ('shoes', 2),
#  ('joakim', 2),
#  ('seunggi', 2),
#  ('youtuber', 2),
#  ('maka', 2),
#  ('pressed', 2),
#  ('uk', 2),
#  ('tips', 2),
#  ('kisah', 2),
#  ('hosted', 2),
#  ('shon', 2),
#  ('thi', 2),
#  ('officers', 2),
#  ('beckett', 2),
#  ('tgk', 2),
#  ('seungyoon', 2),
#  ('nem', 2),
#  ('lah', 2),
#  ('ytd', 2),
#  ('isit', 2),
#  ('lines', 2),
#  ('ashley', 2),
#  ('greene', 2),
#  ('bayne', 2),
#  ('pers', 2),
#  ('muffins', 2),
#  ('shuo', 2),
#  ('cardio', 2),
#  ('diba', 2),
#  ('kenal', 2),
#  ('jumped', 2),
#  ('maharashtra', 2),
#  ('cuddling', 2),
#  ('davido', 2),
#  ('otl', 2),
#  ('starving', 2),
#  ('etienne', 2),
#  ('logitech', 2),
#  ('haters', 2),
#  ('belfast', 2),
#  ('rahe', 2),
#  ('lic', 2),
#  ('dstv', 2),
#  ('cv', 2),
#  ('setiap', 2),
#  ('euro', 2),
#  ('pak', 2),
#  ('torres', 2),
#  ('gerrard', 2),
#  ('bhai', 2),
#  ('bxtch', 2),
#  ('jn', 2),
#  ('trending', 2),
#  ('-y-', 2),
#  ('rai', 2),
#  ('brownies', 2),
#  ('wokingham', 2),
#  ('stans', 2),
#  ('mini', 2),
#  ('attacks', 2),
#  ('killed', 2),
#  ('snapchated', 2),
#  ('ngalong', 2),
#  ('yeshh', 2),
#  ('voy', 2),
#  ('goodevening', 2),
#  ('decor', 2),
#  ('joins', 2),
#  ('nadal', 2),
#  ('puyat', 2),
#  ('nyse', 2),
#  ('fak', 2),
#  ('tunein', 2),
#  ('winamp', 2),
#  ("app's", 2),
#  ('pe', 2),
#  ('bcz', 2),
#  ('clinching', 2),
#  ('pagi', 2),
#  ('editing', 2),
#  ('fifa', 2),
#  ('busog', 2),
#  ('naman', 2),
#  ('glamorgan', 2),
#  ('leicestershire', 2),
#  ('queens', 2),
#  ('mvp', 2),
#  ('hibbert', 2),
#  ('btob', 2),
#  ('sepatu', 2),
#  ('dll', 2),
#  ('moyes', 2),
#  ('dated', 2),
#  ('kgm', 2),
#  ('ano', 2),
#  ('croker', 2),
#  ('masuk', 2),
#  ('multi-color', 2),
#  ('pinata', 2),
#  ('muka', 2),
#  ('ssl', 2),
#  ('ramos', 2),
#  ('x47', 2),
#  ('chances', 2),
#  ('boobs', 2),
#  ('bff', 2),
#  ('refaeli', 2),
#  ('walang', 2),
#  ('biased', 2),
#  ('il', 2),
#  ("1's", 2),
#  ('warmups', 2),
#  ('wings', 2),
#  ('ms', 2),
#  ('jobs', 2),
#  ('bbk', 2),
#  ('76mm', 2),
#  ('lbs', 2),
#  ('cac', 2),
#  ('moms', 2),
#  ('kuya', 2),
#  ('unnie', 2),
#  ('roko', 2),
#  ('aso', 2),
#  ('bottles', 2),
#  ('photoshop', 2),
#  ('shailene', 2),
#  ('woodley', 2),
#  ('padahal', 2),
#  ('kejriwal', 2),
#  ('cameras', 2),
#  ('hyuk', 2),
#  ('uhh', 2),
#  ('chaebol', 2),
#  ('sageuk', 2),
#  ('citi', 2),
#  ('parents', 2),
#  ('dez', 2),
#  ('offline', 2),
#  ('gotti', 2),
#  ('yadong', 2),
#  ('lols', 2),
#  ('elan', 2),
#  ('bo2', 2),
#  ('eurovision', 2),
#  ('england', 2),
#  ('congis', 2),
#  ('pmsl', 2),
#  ('subban', 2),
#  ('chibok', 2),
#  ('filmed', 2),
#  ("africa's", 2),
#  ('beep', 2),
#  ('yoona', 2),
#  ('gah', 2),
#  ('obsessed', 2),
#  ('novak', 2),
#  ('okc', 2),
#  ('bron', 2),
#  ('soldiers', 2),
#  ('fwm', 2),
#  ('youtubers', 2),
#  ('kys', 2),
#  ('papi', 2),
#  ('jelena', 2),
#  ('migos', 2),
#  ('turnt', 2),
#  ('globo', 2),
#  ('digo', 2),
#  ('ac', 2),
#  ('smashwords', 2),
#  ('8th', 2),
#  ('lies', 2),
#  ('usmc', 2),
#  ('semper', 2),
#  ('marines', 2),
#  ('ahahaha', 2),
#  ('raining', 2),
#  ('scheduled', 2),
#  ('jokowi', 2),
#  ('satnite', 2),
#  ('terserah', 2),
#  ('yotv', 2),
#  ('mxm', 2),
#  ('britney', 2),
#  ('wma', 2),
#  ('bachata', 2),
#  ('5th', 2),
#  ('merica', 2),
#  ('italy', 2),
#  ('lopez', 2),
#  ('asking', 2),
#  ('b-agile', 2),
#  ('neg', 2),
#  ('crips', 2),
#  ('loe', 2),
#  ('ct', 2),
#  ('youll', 2),
#  ('expected', 2),
#  ('carthy', 2),
#  ('uan', 2),
#  ('cadena', 2),
#  ('warns', 2),
#  ('jamhooriyat', 2),
#  ('manzoor', 2),
#  ('lmk', 2),
#  ("how's", 2),
#  ('txted', 2),
#  ('earlier', 2),
#  ('tsk', 2),
#  ('junkanoo', 2),
#  ('favoriting', 2),
#  ('que', 2),
#  ('crip', 2),
#  ('saranghae', 2),
#  ('hyung', 2),
#  ('hahahahahah', 2),
#  ('lg', 2),
#  ('wip', 2),
#  ('facts', 2),
#  ('udah', 2),
#  ('genji', 2),
#  ('walk-off', 2),
#  ('ps', 2),
#  ('odi', 2),
#  ('50mm', 2),
#  ('nev', 2),
#  ('digi', 2),
#  ('levitt', 2),
#  ('herbs', 2),
#  ('ayurvedic', 2),
#  ('photobomb', 2),
#  ('arrives', 2),
#  ('witchu', 2),
#  ('abdullah', 2),
#  ('gta', 2),
#  ('jaylin', 2),
#  ('shabu', 2),
#  ('healthcare', 2),
#  ('armour', 2),
#  ('ua', 2),
#  ('sakho', 2),
#  ('lieder', 2),
#  ('ohne', 2),
#  ('izak', 2),
#  ('dazzling', 2),
#  ('marketwatch', 2),
#  ('jsy', 2),
#  ('accounts', 2),
#  ('gopro', 2),
#  ('ambi', 2),
#  ('3volution', 2),
#  ('asheville', 2),
#  ('asda', 2),
#  ('chu', 2),
#  ('loctite', 2),
#  ('ozil', 1),
#  ('opolo', 1),
#  ('bie', 1),
#  ('cantik', 1),
#  ('avedon', 1),
#  ('syempre', 1),
#  ('councillors', 1),
#  ('grecia', 1),
#  ('ony', 1),
#  ('hana', 1),
#  ('maknae', 1),
#  ('jeongguk', 1),
#  ('keelan', 1),
#  ('ff', 1),
#  ('dundalk-carlingford', 1),
#  ('beiji', 1),
#  ('directionas', 1),
#  ('investissement', 1),
#  ('murs', 1),
#  ('chinois', 1),
#  ('drywall', 1),
#  ('heheheh', 1),
#  ('wolfnsheepclothing140', 1),
#  ('cadbury', 1),
#  ('galeris', 1),
#  ('custa', 1),
#  ('taeminho', 1),
#  ('lighstick', 1),
#  ('thanku', 1),
#  ('sekret', 1),
#  ('alegent', 1),
#  ('creighton', 1),
#  ('not-for-profit', 1),
#  ('fai', 1),
#  ('srk', 1),
#  ('salmann', 1),
#  ('khann', 1),
#  ('auchhh', 1),
#  ('a5', 1),
#  ('cannock', 1),
#  ('har-', 1),
#  ('nikkas', 1),
#  ('seatbelt', 1),
#  ('fuhh', 1),
#  ('mtfs', 1),
#  ('0r', 1),
#  ('0h', 1),
#  ('0e', 1),
#  ('cbs', 1),
#  ('havard', 1),
#  ('nordtveit', 1),
#  ('calle', 1),
#  ('gordita', 1),
#  ('nightlife', 1),
#  ('blocks', 1),
#  ('lundquist', 1),
#  ('saves', 1),
#  ('rds', 1),
#  ('clues', 1),
#  ('peppa', 1),
#  ('eeak', 1),
#  ('meen', 1),
#  ('lyshaa', 1),
#  ('oll', 1),
#  ("good'o", 1),
#  ('sungjong', 1),
#  ('seongyeol', 1),
#  ('myungsoo', 1),
#  ('sg', 1),
#  ('amore', 1),
#  ('vinto', 1),
#  ('kcu', 1),
#  ('cosplaying', 1),
#  ('condom', 1),
#  ('asu', 1),
#  ('kuru', 1),
#  ('kara', 1),
#  ('jimin', 1),
#  ('angpaos', 1),
#  ('jungkook', 1),
#  ('angpao', 1),
#  ('alpukat', 1),
#  ('madu', 1),
#  ('banget', 1),
#  ('mq', 1),
#  ('centreville', 1),
#  ('eminado', 1),
#  ('goodluck', 1),
#  ('surulere', 1),
#  ('timeout', 1),
#  ('supporters', 1),
#  ('shourie', 1),
#  ('putting', 1),
#  ('badboy', 1),
#  ('raaaaar', 1),
#  ('daddies', 1),
#  ('-me', 1),
#  ('-dad', 1),
#  ('textin', 1),
#  ('ballerino', 1),
#  ('dafuq', 1),
#  ('niggah', 1),
#  ('titys', 1),
#  ('krabby', 1),
#  ('buns', 1),
#  ('kinds', 1),
#  ('pda', 1),
#  ('channing', 1),
#  ('tatum', 1),
#  ('marwan', 1),
#  ('asmar', 1),
#  ('writes', 1),
#  ('dawwg', 1),
#  ('needto', 1),
#  ('enright', 1),
#  ('lonergan', 1),
#  ('cats', 1),
#  ('kna', 1),
#  ('blik', 1),
#  ('jga', 1),
#  ('bnp', 1),
#  ('umbro', 1),
#  ('trackies', 1),
#  ('chukkaeee', 1),
#  ('enda', 1),
#  ('poch', 1),
#  ('kena', 1),
#  ('kalau', 1),
#  ('hisap', 1),
#  ('aca', 1),
#  ('ayudando', 1),
#  ('spam', 1),
#  ('inte', 1),
#  ('prateik', 1),
#  ('babbar', 1),
#  ("dwp'14", 1),
#  ('zedd', 1),
#  ('jews', 1),
#  ('throwg', 1),
#  ('privilg', 1),
#  ('camps', 1),
#  ('locc', 1),
#  ('buttler', 1),
#  ('senanayake', 1),
#  ('mathews', 1),
#  ('ov', 1),
#  ('alcon', 1),
#  ('receives', 1),
#  ('chmp', 1),
#  ('simbrinz', 1),
#  ('rollingstone', 1),
#  ('zimuvuta', 1),
#  ('gwamba', 1),
#  ('cookerby', 1),
#  ('maurkice', 1),
#  ('pouncey', 1),
#  ('jace', 1),
#  ('annabeth', 1),
#  ('karlie', 1),
#  ('kloss', 1),
#  ('chanel', 1),
#  ('haute', 1),
#  ('couture', 1),
#  ('amd', 1),
#  ('introduces', 1),
#  ('eyefinity', 1),
#  ('notebooks', 1),
#  ('enduro', 1),
#  ('info-pc', 1),
#  ('lauren', 1),
#  ...]

# %%
a = []
for key, item in tag.items():
    a.append(item[0])
    
fdist = nltk.FreqDist(a) 
fdist
# Out:
# FreqDist({'!': 2218,
#           '#': 432,
#           '$': 70,
#           '&': 15,
#           ')': 2,
#           ',': 4,
#           '@': 2024,
#           'A': 592,
#           'D': 24,
#           'E': 28,
#           'G': 190,
#           'L': 96,
#           'N': 2593,
#           'O': 64,
#           'P': 67,
#           'R': 179,
#           'S': 16,
#           'T': 6,
#           'U': 940,
#           'V': 1197,
#           'Y': 1,
#           'Z': 22,
#           '^': 1916,
#           'leaveayoutubecomment': 1,
#           'northside': 1,
#           '~': 2})

# %%
sorted(fdist,key=fdist.get, reverse=True)
# Out:
# ['N',
#  '!',
#  '@',
#  '^',
#  'V',
#  'U',
#  'A',
#  '#',
#  'G',
#  'R',
#  'L',
#  '$',
#  'P',
#  'O',
#  'E',
#  'D',
#  'Z',
#  'S',
#  '&',
#  'T',
#  ',',
#  '~',
#  ')',
#  'Y',
#  'leaveayoutubecomment',
#  'northside']

# %%
tag
# Out:
# {'rt': ('~', '0.4510'),
#  '@teddyferrari1': ('@', '0.9989'),
#  'ah': ('!', '0.9960'),
#  '@datzmenoni': ('@', '0.9990'),
#  'why': ('R', '0.8527'),
#  'sub': ('N', '0.9591'),
#  'ozil': ('^', '0.6393'),
#  '@lexzydoo_ab': ('@', '0.9990'),
#  'opolo': ('!', '0.6633'),
#  'eyes': ('N', '0.9459'),
#  'u': ('O', '0.9843'),
#  'no': ('!', '0.9253'),
#  'fit': ('V', '0.5119'),
#  'open': ('V', '0.5185'),
#  'have': ('V', '0.9703'),
#  'a': ('D', '0.8948'),
#  'very': ('R', '0.9132'),
#  'sexy': ('A', '0.9845'),
#  'header': ('N', '0.9654'),
#  '@jaibrooks1': ('@', '0.9989'),
#  'rawr': ('!', '0.9815'),
#  'i': ('O', '0.9651'),
#  'miss': ('V', '0.6716'),
#  'my': ('D', '0.8420'),
#  'bie': ('^', '0.8871'),
#  'where': ('R', '0.9493'),
#  'wanna': ('V', '0.9079'),
#  'out': ('T', '0.6015'),
#  'wif': ('!', '0.4851'),
#  'me': ('O', '0.9918'),
#  'wonderful': ('A', '0.9407'),
#  'day': ('N', '0.9236'),
#  'like': ('P', '0.7012'),
#  'swan': ('N', '0.8017'),
#  'haha': ('!', '0.9993'),
#  'cantik': ('!', '0.4007'),
#  '@historyinpics': ('@', '0.9990'),
#  'julie': ('^', '0.9868'),
#  'christie': ('^', '0.9961'),
#  'photograph': ('N', '0.9761'),
#  'by': ('P', '0.9649'),
#  'richard': ('^', '0.9919'),
#  'avedon': ('^', '0.7324'),
#  'http://t.co/gscav8o0ik': ('U', '0.9940'),
#  '@fvckxhemmings': ('@', '0.9990'),
#  'did': ('V', '0.9560'),
#  'calum': ('^', '0.6147'),
#  'slip': ('V', '0.6211'),
#  'omfg': ('!', '0.9968'),
#  '@daviddarkshade': ('@', '0.9990'),
#  'and': ('&', '0.9981'),
#  'you': ('O', '0.9627'),
#  'didnt': ('V', '0.8554'),
#  'make': ('V', '0.8257'),
#  'this': ('O', '0.5028'),
#  'brah': ('N', '0.8518'),
#  'friend': ('N', '0.8072'),
#  'jack': ('^', '0.9567'),
#  'storm': ('N', '0.9279'),
#  '@xoxoxyareli': ('@', '0.9989'),
#  '@billmillerprobz': ('@', '0.9990'),
#  'pshh': ('!', '0.9912'),
#  'went': ('V', '0.9059'),
#  'got': ('V', '0.7838'),
#  'mine': ('O', '0.9042'),
#  'done': ('V', '0.8666'),
#  'regardless': ('R', '0.4504'),
#  'im': ('L', '0.9789'),
#  'sick': ('A', '0.9401'),
#  'of': ('P', '0.8953'),
#  'not': ('R', '0.9628'),
#  'being': ('V', '0.9770'),
#  'able': ('A', '0.9036'),
#  'to': ('P', '0.9511'),
#  'be': ('V', '0.9569'),
#  'girl': ('N', '0.8631'),
#  '@tindency': ('@', '0.9986'),
#  'syempre': ('G', '0.3293'),
#  'in': ('P', '0.8576'),
#  'the': ('D', '0.9792'),
#  'right': ('!', '0.8610'),
#  'age': ('N', '0.9020'),
#  'hahaha': ('!', '0.9987'),
#  '@khalilbrown_': ('@', '0.9990'),
#  'shit': ('N', '0.6894'),
#  'rockin': ('V', '0.7299'),
#  'go': ('V', '0.8465'),
#  'head': ('N', '0.9348'),
#  'show': ('N', '0.8348'),
#  'that': ('O', '0.7135'),
#  'bria': ('^', '0.7751'),
#  '@kpoplover727': ('@', '0.9989'),
#  'words': ('N', '0.7885'),
#  'describe': ('V', '0.9444'),
#  'exo': ('^', '0.7330'),
#  'luhan': ('^', '0.9399'),
#  'is': ('V', '0.9892'),
#  'pain': ('N', '0.9899'),
#  'chanyeol': ('^', '0.6161'),
#  'sex': ('N', '0.8990'),
#  'sehun': ('^', '0.7096'),
#  'porn': ('N', '0.4685'),
#  '@michael_heaver': ('@', '0.9990'),
#  'ukip': ('^', '0.5247'),
#  'has': ('V', '0.9464'),
#  'had': ('V', '0.9560'),
#  'two': ('$', '0.9238'),
#  'councillors': ('N', '0.9856'),
#  'elected': ('V', '0.9316'),
#  'northern': ('A', '0.7336'),
#  'ireland': ('^', '0.9046'),
#  'today': ('N', '0.9895'),
#  'marvellous': ('A', '0.9740'),
#  '@kam_maynee': ('@', '0.9990'),
#  'lol': ('!', '0.9995'),
#  'cause': ('P', '0.4706'),
#  'said': ('V', '0.9555'),
#  'woulda': ('V', '0.6478'),
#  'been': ('V', '0.9227'),
#  'falling': ('V', '0.9709'),
#  'along': ('P', '0.3675'),
#  'with': ('P', '0.9671'),
#  '@raqueldiosdado': ('@', '0.9990'),
#  'yea': ('!', '0.9970'),
#  'was': ('V', '0.9773'),
#  'gonna': ('V', '0.9473'),
#  'hit': ('V', '0.7971'),
#  'up': ('T', '0.8440'),
#  'but': ('&', '0.9901'),
#  'guess': ('V', '0.9298'),
#  '@_nicolebeans': ('@', '0.9990'),
#  'okay': ('!', '0.9857'),
#  'well': ('!', '0.9664'),
#  'at': ('P', '0.9712'),
#  'least': ('A', '0.8125'),
#  'know': ('V', '0.9285'),
#  'other': ('A', '0.9271'),
#  'blog': ('N', '0.7796'),
#  "you've": ('L', '0.8988'),
#  'dying': ('V', '0.9948'),
#  'hide': ('V', '0.8775'),
#  'he': ('O', '0.9777'),
#  'obvi': ('!', '0.4071'),
#  'doesnt': ('V', '0.9281'),
#  'understand': ('V', '0.8868'),
#  '#ballislife': ('#', '0.9662'),
#  'http://t.co/wbx9h8jndm': ('U', '0.9940'),
#  '@_queencliffordx': ('@', '0.9990'),
#  'friends': ('N', '0.8548'),
#  'grecia': ('!', '0.7267'),
#  '@iisuperwomanii': ('@', '0.9990'),
#  'just': ('R', '0.9975'),
#  'love': ('N', '0.6603'),
#  'way': ('N', '0.5969'),
#  'are': ('V', '0.9783'),
#  'your': ('D', '0.5467'),
#  'fun': ('N', '0.6011'),
#  'personality': ('N', '0.9492'),
#  'how': ('R', '0.9435'),
#  'arent': ('V', '0.5357'),
#  'afraid': ('A', '0.9357'),
#  'express': ('N', '0.4551'),
#  'yourself': ('O', '0.8983'),
#  'so': ('R', '0.5317'),
#  'openly': ('R', '0.9765'),
#  'on': ('P', '0.8343'),
#  'youtube': ('^', '0.7375'),
#  '#amazon': ('#', '0.9601'),
#  'usa': ('^', '0.5716'),
#  'spalding': ('^', '0.7826'),
#  'nba': ('^', '0.6349'),
#  'street': ('N', '0.6770'),
#  '#basketball': ('#', '0.8912'),
#  'http://t.co/eybuqyi0ms': ('U', '0.9940'),
#  '@graemeforsyth': ('@', '0.9990'),
#  'ony': ('!', '0.3173'),
#  'doing': ('V', '0.9845'),
#  'piss': ('V', '0.7769'),
#  'off': ('T', '0.4522'),
#  'everyone': ('N', '0.9747'),
#  'tl': ('N', '0.7454'),
#  '@sebyul': ('@', '0.9989'),
#  'haru': ('!', '0.4714'),
#  'hana': ('^', '0.8544'),
#  'q': ('G', '0.4954'),
#  'something': ('N', '0.9754'),
#  "can't": ('V', '0.9853'),
#  'do': ('V', '0.9687'),
#  'despite': ('P', '0.7204'),
#  'golden': ('A', '0.4845'),
#  'maknae': ('N', '0.5840'),
#  'jeongguk': ('!', '0.4198'),
#  'talk': ('V', '0.7768'),
#  'studying': ('V', '0.9966'),
#  'laughs': ('V', '0.9102'),
#  'dremel': ('^', '0.5729'),
#  'sm844': ('!', '0.3248'),
#  'crown': ('N', '0.8266'),
#  'molding': ('N', '0.5532'),
#  'guide': ('N', '0.8730'),
#  '1)buy': ('$', '0.4530'),
#  'new': ('A', '0.9552'),
#  'http://t.co/jlixvido8d': ('U', '0.9940'),
#  'conor': ('^', '0.9016'),
#  'keelan': ('^', '0.7996'),
#  'ff': ('!', '0.4474'),
#  'polling': ('N', '0.6477'),
#  'sixth': ('A', '0.8355'),
#  'first': ('A', '0.7263'),
#  'preference': ('N', '0.9804'),
#  'votes': ('N', '0.8823'),
#  'dundalk-carlingford': ('^', '0.4749'),
#  '#le14': ('#', '0.9121'),
#  '#louth': ('#', '0.7611'),
#  '@plssmalik': ('@', '0.9990'),
#  '#1dnewsongiwillsurvive': ('#', '0.9139'),
#  'eu': ('^', '0.6213'),
#  'amo': ('!', '0.9468'),
#  'vcs': ('!', '0.2847'),
#  'esse': ('!', '0.3023'),
#  'fandom': ('N', '0.5736'),
#  'mim': ('!', '0.3912'),
#  'beiji': ('!', '0.3507'),
#  'directionas': ('!', '0.2679'),
#  'investissement': ('!', '0.2729'),
#  'cape': ('N', '0.7193'),
#  'coral': ('A', '0.5561'),
#  'murs': ('^', '0.5501'),
#  'chinois': ('^', '0.2594'),
#  'chinese': ('N', '0.3268'),
#  'drywall': ('N', '0.9207'),
#  'http://t.co/ffsbrpb2x3': ('U', '0.9940'),
#  'via': ('P', '0.7478'),
#  '@youtube': ('@', '0.9990'),
#  '@creatiinggfx': ('@', '0.9990'),
#  '@scorestreakshq1': ('@', '0.9989'),
#  'ight': ('!', '0.9912'),
#  'what': ('O', '0.9490'),
#  'nigga': ('N', '0.5857'),
#  '@jpaulinel': ('@', '0.9990'),
#  'heheheh': ('!', '0.9977'),
#  'youu': ('O', '0.8908'),
#  'ate': ('V', '0.9286'),
#  'jean': ('^', '0.9727'),
#  'feelin': ('V', '0.8916'),
#  'brand': ('N', '0.6236'),
#  'wolfnsheepclothing140': ('!', '0.4347'),
#  'http://t.co/azde27cbhd': ('U', '0.9940'),
#  '@dxoxoluhandeer': ('@', '0.9990'),
#  'eating': ('V', '0.9823'),
#  'cadbury': ('^', '0.7094'),
#  'now': ('R', '0.9613'),
#  'xd': ('E', '0.9306'),
#  'galeris': ('^', '0.2615'),
#  'tag': ('N', '0.8394'),
#  'n': ('&', '0.7343'),
#  'custa': ('!', '0.6063'),
#  'nd': ('&', '0.7158'),
#  '#wmajustinbieber': ('#', '0.9199'),
#  '@mentalbreakdawn': ('@', '0.9990'),
#  'taeminho': ('!', '0.2794'),
#  'lighstick': ('!', '0.3281'),
#  'arrived': ('V', '0.9460'),
#  'thanku': ('!', '0.6082'),
#  '@2minshipperindo': ('@', '0.9989'),
#  '@tmncy95': ('@', '0.9987'),
#  '@minflames': ('@', '0.9990'),
#  'http://t.co/h031oliqsv': ('U', '0.9940'),
#  '@imgooby': ('@', '0.9980'),
#  'zoom': ('N', '0.3123'),
#  'c': ('G', '0.3278'),
#  'an': ('D', '0.7642'),
#  'sekret': ('N', '0.5331'),
#  'mesage': ('N', '0.8145'),
#  'http://t.co/wahejeh987': ('U', '0.9940'),
#  '@emilydavison196': ('@', '0.9989'),
#  '@carolinemckiben': ('@', '0.9990'),
#  'will': ('V', '0.9478'),
#  'appreciate': ('V', '0.9290'),
#  '#urafegit': ('#', '0.8825'),
#  'kno': ('!', '0.4740'),
#  'dat': ('O', '0.4790'),
#  'aint': ('V', '0.7028'),
#  'bad': ('A', '0.9370'),
#  'bitch': ('N', '0.8507'),
#  'dats': ('L', '0.8895'),
#  'knock': ('V', '0.4912'),
#  '#job': ('#', '0.8552'),
#  '#omaha': ('#', '0.9306'),
#  'receptionist': ('N', '0.9482'),
#  'florence': ('^', '0.9428'),
#  'clinic': ('N', '0.7260'),
#  'ft': ('V', '0.6816'),
#  'omaha': ('^', '0.8990'),
#  'alegent': ('!', '0.3877'),
#  'creighton': ('^', '0.9759'),
#  'health': ('N', '0.8865'),
#  'largest': ('A', '0.9246'),
#  'not-for-profit': ('A', '0.7440'),
#  'fai': ('G', '0.4893'),
#  'http://t.co/2mehl04rr8': ('U', '0.9940'),
#  'srk': ('^', '0.5645'),
#  'salmann': ('^', '0.9222'),
#  'khann': ('^', '0.7531'),
#  'auchhh': ('!', '0.5279'),
#  'shoo': ('!', '0.8867'),
#  'handsome': ('A', '0.9599'),
#  'southbound': ('N', '0.5747'),
#  'between': ('P', '0.9126'),
#  'a47': ('^', '0.3253'),
#  'near': ('P', '0.8636'),
#  'hinckley': ('^', '0.8312'),
#  'west': ('!', '0.3538'),
#  'east': ('A', '0.3448'),
#  'a5': ('$', '0.3095'),
#  'from': ('P', '0.9750'),
#  'cannock': ('^', '0.5351'),
#  'towards': ('P', '0.9647'),
#  'har-': ('!', '0.9748'),
#  'http://t.co/xcwo5xdivj': ('U', '0.9940'),
#  '@1dalert': ('@', '0.9981'),
#  'guys': ('N', '0.9762'),
#  'picture': ('N', '0.9454'),
#  'zayn': ('^', '0.9227'),
#  'old': ('A', '0.9547'),
#  'also': ('R', '0.9524'),
#  'can': ('V', '0.9763'),
#  'see': ('V', '0.8335'),
#  'niall': ('^', '0.9486'),
#  'standing': ('V', '0.9906'),
#  'next': ('A', '0.4810'),
#  'him': ('O', '0.8980'),
#  "wouldn't": ('V', '0.8013'),
#  'crowd': ('N', '0.9422'),
#  'good': ('A', '0.9644'),
#  'mood': ('N', '0.9670'),
#  'cus': ('P', '0.5458'),
#  'music': ('N', '0.9810'),
#  '@fanzorro': ('@', '0.9990'),
#  'wait': ('V', '0.9113'),
#  'infact': ('L', '0.3453'),
#  '@yung_btee': ('@', '0.9990'),
#  'most': ('R', '0.7557'),
#  'zulu': ('^', '0.5498'),
#  'nikkas': ('N', '0.8296'),
#  'fore': ('!', '0.3452'),
#  'skin': ('N', '0.9736'),
#  'they': ('O', '0.9737'),
#  'smell': ('V', '0.5287'),
#  '@_1dslovakia': ('@', '0.9989'),
#  '#new': ('#', '0.6305'),
#  'stage': ('N', '0.8796'),
#  'croke': ('^', '0.8576'),
#  'park': ('N', '0.5751'),
#  'dublin': ('^', '0.7963'),
#  'http://t.co/ejy8zdiui8': ('U', '0.9940'),
#  '@horantitties': ('@', '0.9990'),
#  'harrys': ('L', '0.3826'),
#  'reaction': ('N', '0.9758'),
#  'when': ('R', '0.9425'),
#  'let': ('V', '0.8916'),
#  'play': ('V', '0.8616'),
#  'hes': ('L', '0.7174'),
#  'cute': ('A', '0.9673'),
#  'omg': ('!', '0.9978'),
#  '#teamniall': ('#', '0.9351'),
#  'http://t.co/cljucr0rrh': ('U', '0.9940'),
#  'expect': ('V', '0.9066'),
#  'drive': ('N', '0.7405'),
#  'california': ('^', '0.9121'),
#  'for': ('P', '0.9910'),
#  'court': ('N', '0.7776'),
#  'back': ('R', '0.5723'),
#  'seatbelt': ('N', '0.9492'),
#  'ticket': ('N', '0.9528'),
#  'fuhh': ('!', '0.7061'),
#  'thattt': ('O', '0.5806'),
#  '@vilde_hr': ('@', '0.9986'),
#  'literally': ('R', '0.9938'),
#  'made': ('V', '0.9295'),
#  'whole': ('A', '0.8267'),
#  'complete': ('A', '0.6033'),
#  'g': ('!', '0.4604'),
#  'ill': ('L', '0.9564'),
#  'stay': ('V', '0.6675'),
#  'home': ('N', '0.8327'),
#  'b4': ('P', '0.3997'),
#  'party': ('N', '0.9406'),
#  'bunch': ('N', '0.8612'),
#  'fake': ('A', '0.9440'),
#  'mtfs': ('!', '0.2710'),
#  '0r': ('&', '0.4586'),
#  '0h': ('!', '0.9789'),
#  '0e': (',', '0.3122'),
#  'pss': ('G', '0.2353'),
#  'cbs': ('^', '0.3592'),
#  'end': ('N', '0.8614'),
#  '1st': ('A', '0.5809'),
#  'recap': ('N', '0.5820'),
#  'http://t.co/qkkmsjop1o': ('U', '0.9940'),
#  '@arse2mouse': ('@', '0.9988'),
#  'their': ('D', '0.7901'),
#  'number': ('N', '0.9680'),
#  '8(cb': ('$', '0.8325'),
#  'havard': ('^', '0.4086'),
#  'nordtveit': ('!', '0.6535'),
#  'arsenal': ('^', '0.7016'),
#  'youth': ('N', '0.6262'),
#  'reserve': ('N', '0.7416'),
#  'player': ('N', '0.9751'),
#  '@bbcsporf': ('@', '0.9989'),
#  'exclusive': ('A', '0.9362'),
#  'footage': ('N', '0.9644'),
#  'vincent': ('^', '0.9698'),
#  'kompany': ('^', '0.5954'),
#  'going': ('V', '0.9829'),
#  'yaya': ('!', '0.9597'),
#  'toure': ('^', '0.9203'),
#  'after': ('P', '0.8092'),
#  'telling': ('V', '0.9826'),
#  'leaving': ('V', '0.9745'),
#  'https://t.co/wxa0klstoh': ('U', '0.9940'),
#  'streaming': ('V', '0.6955'),
#  'shakira': ('^', '0.8677'),
#  'feat': ('!', '0.4418'),
#  'residente': ('!', '0.4027'),
#  'calle': ('!', '0.4586'),
#  'gordita': ('N', '0.4297'),
#  'http://t.co/a2v5jttvzj': ('U', '0.9940'),
#  "ct/ma's": ('^', '0.3520'),
#  'nightlife': ('N', '0.8138'),
#  'website': ('N', '0.6082'),
#  '@safiasharif_xox': ('@', '0.9990'),
#  'wtf': ('!', '0.9909'),
#  "i've": ('L', '0.9746'),
#  'only': ('R', '0.7668'),
#  'seen': ('V', '0.9406'),
#  'weaver': ('^', '0.6587'),
#  'more': ('A', '0.4885'),
#  'blocks': ('N', '0.7737'),
#  'than': ('P', '0.9031'),
#  'lundquist': ('^', '0.5533'),
#  'saves': ('V', '0.9808'),
#  'ha': ('!', '0.9963'),
#  'rds': ('N', '0.6611'),
#  'john': ('^', '0.9766'),
#  'mayer': ('^', '0.9861'),
#  'xo': ('E', '0.8066'),
#  'beyonce': ('^', '0.8206'),
#  'cover': ('N', '0.7782'),
#  'http://t.co/dpwsakocj2': ('U', '0.9940'),
#  'adore': ('V', '0.8128'),
#  'remix': ('N', '0.8273'),
#  'miley': ('^', '0.7151'),
#  'cyrus': ('^', '0.9685'),
#  'cedric': ('^', '0.8611'),
#  'gervais': ('^', '0.9258'),
#  '@bootygangcult': ('@', '0.9990'),
#  'mom': ('N', '0.7188'),
#  "let's": ('L', '0.9792'),
#  'watch': ('V', '0.8421'),
#  'blues': ('N', '0.7170'),
#  'clues': ('N', '0.9745'),
#  'son': ('N', '0.8521'),
#  'gon': ('V', '0.9396'),
#  'kill': ('V', '0.8244'),
#  'http://t.co/pwarsyqezv': ('U', '0.9900'),
#  '@jason_om': ('@', '0.9986'),
#  'poll': ('N', '0.8979'),
#  'which': ('D', '0.7716'),
#  'would': ('V', '0.9736'),
#  'cut': ('N', '0.8005'),
#  '@qanda': ('@', '0.9980'),
#  'v': ('!', '0.2960'),
#  'peppa': ('^', '0.3234'),
#  'pig': ('N', '0.8976'),
#  '@theheraldsun': ('@', '0.9990'),
#  '#auspol': ('#', '0.9154'),
#  '#abc': ('#', '0.9524'),
#  'http://t.co/chaadb09aq': ('U', '0.9940'),
#  'eeak': ('!', '0.4514'),
#  'meen': ('V', '0.3482'),
#  'lyshaa': ('!', '0.4523'),
#  ':d': ('E', '0.9891'),
#  '@alyshays': ('@', '0.9986'),
#  'keep': ('V', '0.7901'),
#  'save': ('V', '0.9359'),
#  'relationship': ('N', '0.9501'),
#  'seeing': ('V', '0.9803'),
#  'oll': ('!', '0.7686'),
#  'dogg': ('N', '0.5268'),
#  'again': ('R', '0.9571'),
#  "good'o": ('!', '0.9913'),
#  '@5sos_daily': ('@', '0.9990'),
#  'luke': ('^', '0.9439'),
#  'kylie': ('^', '0.9763'),
#  'stylist': ('N', '0.9481'),
#  'http://t.co/5glsteqxcf': ('U', '0.9940'),
#  '@lyeolnam': ('@', '0.9989'),
#  'pls': ('!', '0.4742'),
#  'sungjong': ('^', '0.5884'),
#  'last': ('A', '0.8954'),
#  'romeo': ('^', '0.9130'),
#  'card': ('N', '0.8120'),
#  'want': ('V', '0.9638'),
#  'seongyeol': ('!', '0.3568'),
#  'or': ('&', '0.9822'),
#  'myungsoo': ('^', '0.7373'),
#  'sg': ('^', '0.8570'),
#  '@hemmings_taco': ('@', '0.9990'),
#  'dm': ('N', '0.3768'),
#  'hemmings': ('^', '0.7174'),
#  'mbf': ('^', '0.8909'),
#  'bc': ('P', '0.5850'),
#  'actually': ('R', '0.9907'),
#  'them': ('O', '0.9105'),
#  'http://t.co/pvxsqk1cva': ('U', '0.9940'),
#  '@pragarassongs': ('@', '0.9990'),
#  'christian': ('^', '0.9754'),
#  'pace': ('N', '0.9555'),
#  'pt': ('N', '0.7422'),
#  'amore': ('!', '0.4259'),
#  'hai': ('!', '0.9865'),
#  'vinto': ('!', '0.3095'),
#  'tu': ('G', '0.3641'),
#  '#amici13': ('#', '0.9131'),
#  'http://t.co/nviyl66x8m': ('U', '0.9940'),
#  '@markennis': ('@', '0.9990'),
#  'dan': ('^', '0.8680'),
#  'kcu': ('!', '0.5288'),
#  'alum': ('N', '0.9618'),
#  'funny': ('A', '0.9910'),
#  'songs': ('N', '0.9807'),
#  'calls': ('V', '0.7427'),
#  'himself': ('O', '0.8273'),
#  'whiteboy': ('!', '0.8032'),
#  'dj': ('^', '0.5610'),
#  '@miketokes': ('@', '0.9990'),
#  'sorry': ('!', '0.5410'),
#  'bout': ('P', '0.5620'),
#  'homie': ('N', '0.6474'),
#  'check': ('V', '0.6567'),
#  'dms': ('N', '0.8227'),
#  'get': ('V', '0.9655'),
#  'chance': ('N', '0.8172'),
#  'who': ('O', '0.9764'),
#  "i'm": ('L', '0.9890'),
#  'cosplaying': ('V', '0.8638'),
#  "it's": ('L', '0.9926'),
#  'still': ('R', '0.9849'),
#  'as': ('P', '0.7377'),
#  'comicon': ('^', '0.5170'),
#  '@tt_shake': ('@', '0.9980'),
#  'wear': ('V', '0.8083'),
#  'condom': ('N', '0.8987'),
#  "don't": ('V', '0.9973'),
#  'worry': ('V', '0.9098'),
#  'about': ('P', '0.8950'),
#  'pullin': ('V', '0.6557'),
#  '@mika90628': ('@', '0.9988'),
#  'woah': ('!', '0.9968'),
#  'song': ('N', '0.9799'),
#  'oppa': ('!', '0.9271'),
#  'one': ('$', '0.7703'),
#  'favourite': ('!', '0.3852'),
#  'asu': ('^', '0.3076'),
#  'wa': ('^', '0.5235'),
#  'kuru': ('!', '0.5286'),
#  'kara': ('^', '0.8563'),
#  '@ashley_twt': ('@', '0.9987'),
#  'jimin': ('^', '0.2736'),
#  'it': ('O', '0.9694'),
#  'if': ('P', '0.9711'),
#  'asked': ('V', '0.9670'),
#  'angpaos': ('^', '0.2546'),
#  'jungkook': ('!', '0.3030'),
#  'does': ('V', '0.9782'),
#  'look': ('V', '0.8183'),
#  'aunty': ('N', '0.7210'),
#  'uncle': ('N', '0.8103'),
#  'happy': ('A', '0.9389'),
#  'bigger': ('A', '0.8993'),
#  'angpao': ('!', '0.6230'),
#  'alpukat': ('!', '0.3936'),
#  'madu': ('!', '0.4231'),
#  'yummy': ('A', '0.4298'),
#  'manis': ('^', '0.2958'),
#  'banget': ('!', '0.3301'),
#  'wrap': ('N', '0.4458'),
#  'our': ('D', '0.8438'),
#  'month': ('N', '0.9362'),
#  'moscato': ('N', '0.4563'),
#  'host': ('N', '0.5892'),
#  'tasting': ('N', '0.7024'),
#  '#socialhour': ('#', '0.9191'),
#  'http://t.co/gd2czn6cki': ('U', '0.9940'),
#  'http://t.co/yonfydyojb': ('U', '0.9900'),
#  '@minquannn': ('@', '0.9980'),
#  'mq': ('!', '0.2940'),
#  'easy': ('A', '0.9319'),
#  'doto': ('!', '0.4958'),
#  '#feedforlife': ('#', '0.9201'),
#  '@greatamerrest': ('@', '0.9990'),
#  'tap': ('N', '0.6669'),
#  '@sweetwater_gar': ('@', '0.9990'),
#  'centreville': ('^', '0.9202'),
#  'chipotle': ('^', '0.5669'),
#  'porter': ('^', '0.8763'),
#  '@thevampsrob': ('@', '0.9989'),
#  'yall': ('O', '0.6750'),
#  'worried': ('A', '0.3540'),
#  'fact': ('N', '0.8446'),
#  'smoking': ('V', '0.9631'),
#  'weed': ('N', '0.6761'),
#  'wasnt': ('V', '0.4753'),
#  'even': ('R', '0.9851'),
#  'wearing': ('V', '0.9581'),
#  'seat': ('N', '0.9305'),
#  'belt': ('N', '0.9455'),
#  '@bhadoosky': ('@', '0.9990'),
#  'eminado': ('!', '0.4056'),
#  'means': ('V', '0.9220'),
#  'goodluck': ('!', '0.9793'),
#  'surulere': ('^', '0.8458'),
#  'patience': ('N', '0.9725'),
#  '@donjazzy': ('@', '0.9986'),
#  'must': ('V', '0.9380'),
#  'related': ('A', '0.6586'),
#  'president': ('N', '0.8780'),
#  '@worldstarfunny': ('@', '0.9990'),
#  'lil': ('A', '0.3067'),
#  'years': ('N', '0.8823'),
#  'timeout': ('N', '0.8983'),
#  'http://t.co/bswqzqespg': ('U', '0.9900'),
#  'mango': ('N', '0.4699'),
#  'some': ('D', '0.7045'),
#  'fuckn': ('!', '0.5754'),
#  'real': ('A', '0.7729'),
#  'bjp': ('^', '0.7006'),
#  'supporters': ('N', '0.9806'),
#  'delighted': ('V', '0.4846'),
#  'https://t.co/k06cqv8mqc': ('U', '0.9940'),
#  'shourie': ('^', '0.4027'),
#  'ji': ('!', '0.3876'),
#  'putting': ('V', '0.9707'),
#  '@swapan55': ('@', '0.9989'),
#  'his': ('D', '0.9130'),
#  'place': ('N', '0.9567'),
#  '@sarkar_swati': ('@', '0.9990'),
#  '@sandeepweb': ('@', '0.9990'),
#  '@lisyopenmind': ('@', '0.9990'),
#  '@potteralda': ('@', '0.9987'),
#  '@purrlcat': ('@', '0.9989'),
#  'angy': ('!', '0.4713'),
#  'knows': ('V', '0.9622'),
#  "she's": ('L', '0.9691'),
#  'met': ('V', '0.8031'),
#  'jake': ('^', '0.9907'),
#  'badboy': ('N', '0.6968'),
#  'temper': ('N', '0.9703'),
#  'raaaaar': ('N', '0.6579'),
#  'sugar': ('N', '0.9867'),
#  'daddies': ('N', '0.7752'),
#  'online': ('A', '0.7930'),
#  '-me': ('!', '0.3249'),
#  'gurl': ('!', '0.5561'),
#  '-dad': ('V', '0.4627'),
#  '@bradieboolove': ('@', '0.9990'),
#  'graduation': ('N', '0.9649'),
#  'rehersal': ('N', '0.7969'),
#  'takin': ('V', '0.9875'),
#  'forever': ('R', '0.9802'),
#  'thank': ('V', '0.6008'),
#  'goodness': ('^', '0.4513'),
#  'textin': ('V', '0.7986'),
#  '@onlyonesnacks': ('@', '0.9990'),
#  'sanity': ('N', '0.9226'),
#  '@coelasquid': ('@', '0.9990'),
#  'believe': ('V', '0.9527'),
#  'term': ('N', '0.9733'),
#  'male': ('N', '0.4670'),
#  'ballerina': ('N', '0.9448'),
#  'ballerino': ('!', '0.5710'),
#  'pokemon': ('^', '0.7958'),
#  'dafuq': ('!', '0.9689'),
#  'smh': ('G', '0.9277'),
#  '@juju_elihle': ('@', '0.9990'),
#  'glass': ('N', '0.9166'),
#  'wine': ('N', '0.8876'),
#  '@sazzie_twitt': ('@', '0.9990'),
#  'drunk': ('A', '0.8413'),
#  'd': ('!', '0.3287'),
#  '@averydunn_': ('@', '0.9986'),
#  'k': ('!', '0.3103'),
#  'dolla': ('!', '0.7346'),
#  'sign': ('N', '0.6600'),
#  'gm': ('!', '0.5204'),
#  'nah': ('!', '0.9921'),
#  '@niggeerrich': ('@', '0.9989'),
#  'niggah': ('N', '0.5797'),
#  '@dilipkpandey': ('@', '0.9990'),
#  '@arvindkejriwal': ('@', '0.9990'),
#  'time': ('N', '0.9685'),
#  'try': ('V', '0.8716'),
#  'fight': ('N', '0.5831'),
#  'elction': ('N', '0.3988'),
#  'winning': ('V', '0.9242'),
#  'spirite': ('!', '0.3675'),
#  'defeat': ('V', '0.4013'),
#  'others': ('N', '0.7945'),
#  '@tvvittergod': ('@', '0.9989'),
#  'lmao': ('!', '0.9991'),
#  'her': ('O', '0.5274'),
#  'titys': ('N', '0.3357'),
#  'really': ('R', '0.9938'),
#  'krabby': ('A', '0.4471'),
#  'patty': ('N', '0.6301'),
#  'buns': ('N', '0.9380'),
#  'http://t.co/otvftxstvr': ('U', '0.9900'),
#  "they're": ('L', '0.8765'),
#  'allergic': ('A', '0.8860'),
#  'face': ('N', '0.9357'),
#  '@voodoochild42': ('@', '0.9989'),
#  'insecure': ('A', '0.9761'),
#  'bfs': ('N', '0.5197'),
#  'showin': ('V', '0.6488'),
#  'all': ('D', '0.7257'),
#  'kinds': ('N', '0.7566'),
#  'pda': ('^', '0.6833'),
#  'cuz': ('P', '0.4479'),
#  'came': ('V', '0.8786'),
#  'around': ('P', '0.4644'),
#  'corner': ('N', '0.9667'),
#  'channing': ('^', '0.7716'),
#  'tatum': ('^', '0.7001'),
#  'jonah': ('^', '0.9953'),
#  'hill': ('N', '0.5068'),
#  'take': ('V', '0.9216'),
#  'silly': ('A', '0.9832'),
#  'selfies': ('N', '0.8773'),
#  'fans': ('N', '0.9656'),
#  'http://t.co/k2gqjaajao': ('U', '0.9940'),
#  '#fashion': ('#', '0.8075'),
#  'marwan': ('^', '0.9520'),
#  'asmar': ('!', '0.2416'),
#  'writes': ('V', '0.9716'),
#  'road': ('N', '0.8467'),
#  'ahead': ('R', '0.5145'),
#  'looks': ('V', '0.9461'),
#  'intractable': ('A', '0.9545'),
#  '#libya': ('^', '0.4942'),
#  'http://t.co/d27xalsqdn': ('U', '0.9940'),
#  '@kb32904': ('@', '0.9981'),
#  'labour': ('N', '0.8332'),
#  'weak': ('A', '0.9041'),
#  'round': ('N', '0.7496'),
#  'lizard': ('N', '0.8397'),
#  'point': ('N', '0.9150'),
#  'mention': ('V', '0.7261'),
#  'o': ('!', '0.7684'),
#  'e': ('G', '0.3771'),
#  'dawwg': ('N', '0.8397'),
#  '@shaigoddess': ('@', '0.9989'),
#  'yeah': ('!', '0.9988'),
#  'guy': ('N', '0.7125'),
#  'saying': ('V', '0.9801'),
#  'needto': ('V', '0.5945'),
#  'enright': ('!', '0.5092'),
#  'lonergan': ('^', '0.5723'),
#  'cats': ('N', '0.9500'),
#  'http://t.co/adbusqgfaw': ('U', '0.9900'),
#  'god': ('^', '0.7896'),
#  "didn't": ('V', '0.9947'),
#  'sleep': ('N', '0.6167'),
#  'oh': ('!', '0.9988'),
#  'saw': ('V', '0.9172'),
#  'everything': ('N', '0.9592'),
#  'wat': ('O', '0.9383'),
#  'sooner': ('R', '0.8461'),
#  'later': ('R', '0.7646'),
#  'ko': ('!', '0.4809'),
#  'kna': ('!', '0.4608'),
#  'blik': ('!', '0.4963'),
#  'jga': ('!', '0.5780'),
#  'goes': ('V', '0.9196'),
#  'comes': ('V', '0.9701'),
#  '@natnatnatchiu': ('@', '0.9990'),
#  'method': ('N', '0.9585'),
#  'ponning': ('V', '0.2891'),
#  'school': ('N', '0.9809'),
#  'hahhahaha': ('!', '0.9987'),
#  'http://t.co/xrvmh0dmhc': ('U', '0.9940'),
#  '@mmldn': ('@', '0.9980'),
#  'tell': ('V', '0.7941'),
#  'voted': ('V', '0.9917'),
#  'bnp': ('^', '0.4568'),
#  'umbro': ('^', '0.4087'),
#  'trackies': ('N', '0.8578'),
#  'screw': ('N', '0.6459'),
#  '@rawr_town': ('@', '0.9980'),
#  '@rawr_iudanbo': ('@', '0.9990'),
#  'congratulation': ('!', '0.5142'),
#  '#rawr2ndyearsary': ('#', '0.9212'),
#  'hey': ('!', '0.9986'),
#  'cutie': ('N', '0.8120'),
#  'chukkaeee': ('!', '0.9947'),
#  '\\m/': ('E', '0.8219'),
#  'having': ('V', '0.9803'),
#  'teacher': ('N', '0.9417'),
#  'accept': ('V', '0.9628'),
#  'late': ('A', '0.8833'),
#  'work': ('N', '0.8618'),
#  'probably': ('R', '0.9958'),
#  'worst': ('A', '0.9241'),
#  'thing': ('N', '0.9739'),
#  'ever': ('R', '0.9297'),
#  'little': ('A', '0.9286'),
#  'hw': ('!', '0.6094'),
#  'every': ('D', '0.6681'),
#  'night': ('N', '0.6493'),
#  'na': ('!', '0.6203'),
#  'po': ('!', '0.3639'),
#  'starts': ('V', '0.8848'),
#  's': ('G', '0.7922'),
#  'enda': ('^', '0.5220'),
#  'r': ('V', '0.4589'),
#  'example': ('N', '0.9659'),
#  'saucer': ('A', '0.3652'),
#  'admin': ('N', '0.9223'),
#  'ching': ('!', '0.5046'),
#  'louis': ('^', '0.9366'),
#  'harry': ('^', '0.8785'),
#  'liam': ('^', '0.7120'),
#  'http://t.co/rtb7prldxq': ('U', '0.9940'),
#  'lls': ('!', '0.9665'),
#  'niggas': ('N', '0.8807'),
#  'fallin': ('V', '0.7406'),
#  'short': ('A', '0.9586'),
#  'bitches': ('N', '0.9404'),
#  'neva': ('!', '0.5724'),
#  '@aygarde_': ('@', '0.9986'),
#  'bro': ('N', '0.7862'),
#  'dont': ('V', '0.9006'),
#  'feel': ('V', '0.9161'),
#  'tmrw': ('N', '0.6209'),
#  '@andyhspurs': ('@', '0.9990'),
#  '@stespurs': ('@', '0.9989'),
#  '@pipey78': ('@', '0.9981'),
#  'benitez': ('^', '0.8999'),
#  'earth': ('N', '0.5615'),
#  'leave': ('V', '0.8730'),
#  'napoli': ('^', '0.9533'),
#  'poch': ('^', '0.3548'),
#  'behind': ('P', '0.9369'),
#  'joint': ('N', '0.7835'),
#  'ahhhh': ('!', '0.9987'),
#  '#getdrunk': ('#', '0.8977'),
#  '@raisrzk': ('@', '0.9990'),
#  '@izzuddinzahidi': ('@', '0.9990'),
#  'kena': ('^', '0.5290'),
#  'tweet': ('V', '0.5818'),
#  'kalau': ('!', '0.5437'),
#  'hisap': ('!', '0.6050'),
#  '@emmanuelshannon': ('@', '0.9990'),
#  '#argentinawantsbigbangconcert': ('#', '0.9352'),
#  'aca': ('!', '0.4824'),
#  'ayudando': ('!', '0.5880'),
#  'con': ('N', '0.4743'),
#  'spam': ('N', '0.7439'),
#  'rahway': ('^', '0.8910'),
#  'nj': ('^', '0.7614'),
#  'paramedic': ('N', '0.9061'),
#  'robert': ('^', '0.9656'),
#  'wood': ('^', '0.4543'),
#  'johnson': ('^', '0.8835'),
#  'university': ('N', '0.7547'),
#  'hospital': ('N', '0.9250'),
#  'perform': ('V', '0.9129'),
#  'mobile': ('A', '0.7101'),
#  'inte': ('G', '0.3596'),
#  'http://t.co/renufsgp6i': ('U', '0.9940'),
#  'momma': ('!', '0.4579'),
#  "ain't": ('V', '0.8098'),
#  'live': ('V', '0.4463'),
#  'second': ('A', '0.8282'),
#  'class': ('N', '0.9759'),
#  'prateik': ('!', '0.2369'),
#  'babbar': ('^', '0.9445'),
#  'bengali': ('^', '0.8194'),
#  'film': ('N', '0.8540'),
#  'http://t.co/bvqb1lribh': ('U', '0.9940'),
#  'http://t.co/1j7e3qx0dv': ('U', '0.9940'),
#  '@realstouffer': ('@', '0.9990'),
#  'much': ('A', '0.5576'),
#  'better': ('A', '0.6680'),
#  'bit': ('N', '0.4978'),
#  '@thecamillechen': ('@', '0.9990'),
#  'think': ('V', '0.9624'),
#  'need': ('V', '0.8664'),
#  'wash': ('N', '0.4130'),
#  'posible': ('A', '0.4590'),
#  'peace': ('N', '0.7108'),
#  '@tellemcmainey': ('@', '0.9990'),
#  'till': ('P', '0.8499'),
#  'w/': ('P', '0.4039'),
#  'j': ('G', '0.3173'),
#  'leo': ('^', '0.9607'),
#  'kat': ('^', '0.9425'),
#  'come': ('V', '0.9593'),
#  'replay': ('N', '0.9235'),
#  '@stevemratcliff': ('@', '0.9990'),
#  'worries': ('N', '0.7905'),
#  'weird': ('A', '0.9596'),
#  'name': ('N', '0.9785'),
#  'understandable': ('A', '0.9916'),
#  '@conterasj': ('@', '0.9990'),
#  'lebron': ('^', '0.9495'),
#  'fan': ('N', '0.9084'),
#  'gotta': ('V', '0.9603'),
#  'any': ('D', '0.6983'),
#  'flop': ('N', '0.9234'),
#  'against': ('P', '0.9607'),
#  '@weloverobdyrdek': ('@', '0.9990'),
#  'manny': ('^', '0.5343'),
#  'pacquiao': ('!', '0.4343'),
#  'af': ('R', '0.3529'),
#  'http://t.co/rrw2lb54s4': ('U', '0.9940'),
#  'money': ('N', '0.9305'),
#  "dwp'14": ('^', '0.4607'),
#  'meeting': ('N', '0.7079'),
#  'zedd': ('^', '0.8162'),
#  '@niallofficial': ('@', '0.9990'),
#  'dressin': ('V', '0.8494'),
#  'room': ('N', '0.9307'),
#  'shenanigans': ('N', '0.9322'),
#  'harrystyles': ('!', '0.2007'),
#  'http://t.co/xdupsttiot': ('U', '0.9900'),
#  "won't": ('V', '0.8295'),
#  'mess': ('N', '0.7366'),
#  'hashtag': ('N', '0.5386'),
#  'descent': ('N', '0.9625'),
#  "there's": ('L', '0.7367'),
#  'unity': ('N', '0.9431'),
#  'group': ('N', '0.9274'),
#  'because': ('P', '0.9780'),
#  'everybody': ('N', '0.9116'),
#  'prick': ('N', '0.8972'),
#  'sometimes': ('R', '0.9272'),
#  '@abarba2020': ('@', '0.9987'),
#  'ima': ('L', '0.9573'),
#  'fam': ('N', '0.5520'),
#  'swoop': ('N', '0.9130'),
#  '@aurak4s1h': ('@', '0.9987'),
#  'desain': ('N', '0.3539'),
#  'kamar': ('^', '0.5309'),
#  'anak': ('!', '0.4388'),
#  'ceria': ('!', '0.6084'),
#  'bright': ('A', '0.7080'),
#  'children': ('N', '0.8002'),
#  'design': ('N', '0.9432'),
#  'ideas': ('N', '0.8482'),
#  'http://t.co/5okzixykwx': ('U', '0.9940'),
#  '@femaletexts': ('@', '0.9989'),
#  'public': ('A', '0.7502'),
#  'bae': ('N', '0.9032'),
#  'another': ('D', '0.8794'),
#  'http://t.co/5pyr3rronh': ('U', '0.9940'),
#  'mt': ('!', '0.4541'),
#  '@redsteeze': ('@', '0.9990'),
#  'fucking': ('!', '0.5504'),
#  'jews': ('N', '0.4558'),
#  'always': ('R', '0.9795'),
#  'throwg': ('!', '0.2142'),
#  'holocaust': ('N', '0.7029'),
#  'privilg': ('!', '0.3240'),
#  'ppls': ('N', '0.3846'),
#  'faces': ('V', '0.8199'),
#  'sum1': ('!', '0.3008'),
#  'shld': ('V', '0.6333'),
#  'put': ('V', '0.7836'),
#  'camps': ('N', '0.9443'),
#  'w8': ('!', '0.3994'),
#  '@owillis': ('@', '0.9986'),
#  '@wizkhalifa': ('@', '0.9990'),
#  'locc': ('N', '0.6519'),
#  '@nbafollowtrain': ('@', '0.9990'),
#  'michael': ('^', '0.9892'),
#  'jordan': ('^', '0.9947'),
#  'fav': ('!', '0.4484'),
#  'james': ('^', '0.9951'),
#  'http://t.co/cwhg5cr95q': ('U', '0.9940'),
#  'jos': ('^', '0.3244'),
#  'buttler': ('^', '0.6066'),
#  'senanayake': ('^', '0.3698'),
#  'b': ('V', '0.3261'),
#  'mathews': ('^', '0.8552'),
#  'ov': ('!', '0.4247'),
#  '#cricket': ('#', '0.9100'),
#  '#engvsl': ('#', '0.9066'),
#  'http://t.co/6fnzmwlews': ('U', '0.9940'),
#  ...}
